# %% [markdown]
# # Example Noise
#
# Here we demonstrate an example noise analysis

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd

import glob, json, os
import matplotlib.pyplot as plt

from h5pulsar import Pulsar, FilePulsar
from enterprise.signals import parameter
from enterprise.signals import utils
from enterprise.signals import signal_base
from enterprise.signals import selections
from enterprise.signals.selections import Selection
from enterprise.signals import white_signals
from enterprise.signals import gp_signals
from enterprise.signals import deterministic_signals
import enterprise.constants as const
from enterprise.signals import utils

from enterprise_extensions.blocks import common_red_noise_block
from dr3_noise.models import model_singlepsr_noise
from dr3_noise.model_utils import get_freqs
from dr3_noise.selections import CustomSelections
from enterprise_extensions.sampler import setup_sampler, group_from_params
import enterprise.constants as const
from targeted_cws_ng15.Dists_Parameters import get_parameter_groups_CAW_target

# %matplotlib inline
# %config IPython.matplotlib.backend = "retina"
from matplotlib import rcParams
rcParams["savefig.dpi"] = 300
rcParams["figure.dpi"] = 300

# %% [markdown]
# change directories and such to match your usage

# %%
project_path = '/vast/palmer/home.grace/bbl29/IPTA_DR2_analysis'
scratchdir = '/vast/palmer/scratch/mingarelli/bbl29/IPTA_DR2_analysis/chains'
datadir = f'{basedir}/data/full_ePSRs'  # par/tim location
outdir = f'{scratchdir}/dr2full/crn_pl13_g4p3'  # chain file and other output here
noisedict_path = f'{project_path}/noisedicts/dr2full_stdnoise.json'
if not os.path.isdir(outdir):
    os.mkdir(outdir)
emp_dist_path = f'{project_path}/empdists/dr2full_stdnoise.pkl'

# %% [markdown]
# # read in pulsars

# %%
psrnames = []
psr_paths = glob.glob(f'{project_path}/data/full_ePSRs/J*')
for psr_path in psr_paths:
    psrnames.append(psr_path.split('/')[-1][:-5])
psrnames = np.sort(np.unique(psrnames))

# %%
psrs = []
for psrname in psrnames:
    psrs.append(FilePulsar(f'{datadir}/{psrname}.hdf5'))

# %% [markdown]
# # setup basic enterprise model
#
# This model is intended to correspond to the noise model used for the DR3 GWB paper:
# - Timing model: Linear, use `tm_svd`, use `tm_marg`
# - White noise: EFACs with Gaussian priors, TNEQUAD, ECORR for NANOGrav only. Fixed values using noise dictionary
# - Common red noise: 13-component PL from 1/Tspan
# - Red noise: 30-component PL from 1/Tspan
# - DMv: 30-component PL from 1/Tspan
# - Extra signals: DM dip for J1713 only
#
# We'll set up the model quickly with enterprise_extensions

# %%
Tspan = 952746385.6296968

# %%
crn = common_red_noise_block(psd='powerlaw', prior='log-uniform', Tspan=Tspan,
                             components=13, gamma_val=13/3,
                             logmin=-18, logmax=-12,
                             orf=None, name='crn')

# %%
models = []
for psr in psrs:
    if 'NANOGrav' in psr.flags['pta']:
        inc_ecorr = True
        ecorr_groups_by_PTA = {'NANOGrav':'group'}
    else:
        inc_ecorr = False
        ecorr_groups_by_PTA = None
    efeq_groups_by_PTA = {}
    for pta in np.unique(psr.flags['pta']):
        efeq_groups_by_PTA[pta] = 'group'
    #print(efeq_groups_by_PTA)
    #print(ecorr_groups_by_PTA)
    if psr.name == 'J1713+0747':
        dm_expdip=True
    else:
        dm_expdip=False
    noise = model_singlepsr_noise(psr, Tspan=Tspan, psr_model=True,
                                  # timing
                                  tm_svd=True, tm_marg=True,
                                  # white noise
                                  white_vary=False, tnequad=True, inc_ecorr=inc_ecorr,
                                  efeq_groups=efeq_groups_by_PTA, ecorr_groups=ecorr_groups_by_PTA,
                                  log_equad_min=-10, log_equad_max=-4,
                                  # DM
                                  dm_var=True, dm_type='gp',
                                  dmgp_kernel='diag', dm_psd='powerlaw',
                                  dm_Nfreqs=30,
                                  # solar wind
                                  dm_sw_deter=False,
                                  # dm dip
                                  dm_expdip=dm_expdip, dm_expdip_basename='exp',
                                  dm_expdip_tau_min=np.log10(5), dm_expdip_tau_max=np.log10(500), 
                                  # red noise
                                  log_A_min=-20, log_A_max=-11)
    signals = crn + noise
    models.append(signals(psr))
pta = signal_base.PTA(models)
with open(noisedict_path,'r') as f:
    noise_params = json.load(f)
pta.set_default_params(noise_params)

# %%
print(pta.summary())
# Out:
# enterprise v0.1.dev796+gcb3e25e,  Python v3.10.12
# ==========================================================================================
#
# Signal Name                              Signal Class                   no. Parameters
# ==========================================================================================
# J0030+0451_crn                           FourierBasisGP                 1
#
# Basis shape (Ntoas x N basis functions): (3362, 26)
# N selected toas: 3362
#
# params:
# crn_log10_A:Uniform(pmin=-18, pmax=-12)
# crn_gamma:Constant=4.333333333333333
# __________________________________________________________________________________________
# J0030+0451_marginalizing_linear_timing_model TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0030+0451_red_noise                     FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (3362, 60)
# N selected toas: 3362
#
# params:
# J0030+0451_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J0030+0451_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0030+0451_dm_gp                         BasisGP                        2
#
# Basis shape (Ntoas x N basis functions): (3362, 60)
# N selected toas: 3362
#
# params:
# J0030+0451_dm_gp_log10_A:Uniform(pmin=-20, pmax=-11)
# J0030+0451_dm_gp_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0030+0451_measurement_noise             MeasurementNoise               0
#
# params:
# J0030+0451_430_ASP_efac:Constant=1.1693349995993352
# J0030+0451_430_PUPPI_efac:Constant=0.9805012132694292
# J0030+0451_EFF.EBPP.1360_efac:Constant=1.1138204273060834
# J0030+0451_EFF.EBPP.1410_efac:Constant=0.753789209786396
# J0030+0451_EFF.EBPP.2639_efac:Constant=0.9951184513472493
# J0030+0451_JBO.DFB.1520_efac:Constant=1.0314906623387339
# J0030+0451_L-wide_ASP_efac:Constant=1.1266091701219423
# J0030+0451_L-wide_PUPPI_efac:Constant=1.16374796918102
# J0030+0451_NRT.BON.1400_efac:Constant=1.2119746259796658
# J0030+0451_NRT.BON.1600_efac:Constant=1.5734847684651874
# J0030+0451_NRT.BON.2000_efac:Constant=1.391025551990567
# __________________________________________________________________________________________
# J0030+0451_tnequad                       TNEquadNoise                   0
#
# params:
# J0030+0451_430_ASP_log10_tnequad:Constant=-8.278677090731676
# J0030+0451_430_PUPPI_log10_tnequad:Constant=-5.958832612195742
# J0030+0451_EFF.EBPP.1360_log10_tnequad:Constant=-7.837141494030068
# J0030+0451_EFF.EBPP.1410_log10_tnequad:Constant=-7.385050873114307
# J0030+0451_EFF.EBPP.2639_log10_tnequad:Constant=-7.419997348394892
# J0030+0451_JBO.DFB.1520_log10_tnequad:Constant=-8.055621121988949
# J0030+0451_L-wide_ASP_log10_tnequad:Constant=-8.172527903299278
# J0030+0451_L-wide_PUPPI_log10_tnequad:Constant=-6.4073084832347265
# J0030+0451_NRT.BON.1400_log10_tnequad:Constant=-6.327335048194445
# J0030+0451_NRT.BON.1600_log10_tnequad:Constant=-7.948109714510256
# J0030+0451_NRT.BON.2000_log10_tnequad:Constant=-7.738695032480396
# __________________________________________________________________________________________
# J0030+0451_ecorr_fast-sherman-morrison   EcorrKernelNoise               0
#
# params:
# J0030+0451_430_ASP_log10_ecorr:Constant=-6.563359102912269
# J0030+0451_430_PUPPI_log10_ecorr:Constant=-6.055132200436162
# J0030+0451_L-wide_ASP_log10_ecorr:Constant=-8.347491185404273
# J0030+0451_L-wide_PUPPI_log10_ecorr:Constant=-8.411868143323161
# __________________________________________________________________________________________
# J0034-0534_crn                           FourierBasisGP                 1
#
# Basis shape (Ntoas x N basis functions): (276, 26)
# N selected toas: 276
#
# params:
# crn_log10_A:Uniform(pmin=-18, pmax=-12)
# crn_gamma:Constant=4.333333333333333
# __________________________________________________________________________________________
# J0034-0534_marginalizing_linear_timing_model TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0034-0534_red_noise                     FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (276, 60)
# N selected toas: 276
#
# params:
# J0034-0534_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J0034-0534_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0034-0534_dm_gp                         BasisGP                        2
#
# Basis shape (Ntoas x N basis functions): (276, 60)
# N selected toas: 276
#
# params:
# J0034-0534_dm_gp_log10_A:Uniform(pmin=-20, pmax=-11)
# J0034-0534_dm_gp_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0034-0534_measurement_noise             MeasurementNoise               0
#
# params:
# J0034-0534_NRT.BON.1400_efac:Constant=1.0774323659518035
# J0034-0534_NRT.BON.1600_efac:Constant=2.311196697377723
# J0034-0534_WSRT.P1.328_efac:Constant=1.3869787125948414
# J0034-0534_WSRT.P1.328.C_efac:Constant=1.139484683062738
# J0034-0534_WSRT.P1.382_efac:Constant=0.8176865217589417
# J0034-0534_WSRT.P1.382.C_efac:Constant=1.3827837793772844
# __________________________________________________________________________________________
# J0034-0534_tnequad                       TNEquadNoise                   0
#
# params:
# J0034-0534_NRT.BON.1400_log10_tnequad:Constant=-5.11242564012133
# J0034-0534_NRT.BON.1600_log10_tnequad:Constant=-7.284450416510699
# J0034-0534_WSRT.P1.328_log10_tnequad:Constant=-7.485945786030407
# J0034-0534_WSRT.P1.328.C_log10_tnequad:Constant=-7.998499173554944
# J0034-0534_WSRT.P1.382_log10_tnequad:Constant=-7.75013726924052
# J0034-0534_WSRT.P1.382.C_log10_tnequad:Constant=-7.429147016775263
# __________________________________________________________________________________________
# J0218+4232_crn                           FourierBasisGP                 1
#
# Basis shape (Ntoas x N basis functions): (1196, 26)
# N selected toas: 1196
#
# params:
# crn_log10_A:Uniform(pmin=-18, pmax=-12)
# crn_gamma:Constant=4.333333333333333
# __________________________________________________________________________________________
# J0218+4232_marginalizing_linear_timing_model TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0218+4232_red_noise                     FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (1196, 60)
# N selected toas: 1196
#
# params:
# J0218+4232_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J0218+4232_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0218+4232_dm_gp                         BasisGP                        2
#
# Basis shape (Ntoas x N basis functions): (1196, 60)
# N selected toas: 1196
#
# params:
# J0218+4232_dm_gp_log10_A:Uniform(pmin=-20, pmax=-11)
# J0218+4232_dm_gp_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0218+4232_measurement_noise             MeasurementNoise               0
#
# params:
# J0218+4232_EFF.EBPP.1360_efac:Constant=1.2471711174275195
# J0218+4232_EFF.EBPP.1410_efac:Constant=1.2111670744025338
# J0218+4232_JBO.DFB.1400_efac:Constant=1.4907813739671207
# J0218+4232_JBO.DFB.1520_efac:Constant=1.1462360941486793
# J0218+4232_NRT.BON.1400_efac:Constant=1.1623221825722219
# J0218+4232_NRT.BON.1600_efac:Constant=1.5174001566177662
# J0218+4232_NRT.BON.2000_efac:Constant=1.3456362098162113
# J0218+4232_WSRT.P1.1380_efac:Constant=1.630111679084626
# J0218+4232_WSRT.P1.1380.C_efac:Constant=3.3323572984083576
# J0218+4232_WSRT.P1.328_efac:Constant=1.908742525735098
# J0218+4232_WSRT.P1.328.C_efac:Constant=1.845941865468545
# J0218+4232_WSRT.P1.382_efac:Constant=1.4905303469653441
# J0218+4232_WSRT.P1.382.C_efac:Constant=1.4263221794699952
# __________________________________________________________________________________________
# J0218+4232_tnequad                       TNEquadNoise                   0
#
# params:
# J0218+4232_EFF.EBPP.1360_log10_tnequad:Constant=-7.020522223032893
# J0218+4232_EFF.EBPP.1410_log10_tnequad:Constant=-7.780798795327319
# J0218+4232_JBO.DFB.1400_log10_tnequad:Constant=-7.0470986320911555
# J0218+4232_JBO.DFB.1520_log10_tnequad:Constant=-7.585089946169053
# J0218+4232_NRT.BON.1400_log10_tnequad:Constant=-7.846853016820406
# J0218+4232_NRT.BON.1600_log10_tnequad:Constant=-7.427711670580291
# J0218+4232_NRT.BON.2000_log10_tnequad:Constant=-7.147332223803148
# J0218+4232_WSRT.P1.1380_log10_tnequad:Constant=-7.457447155969477
# J0218+4232_WSRT.P1.1380.C_log10_tnequad:Constant=-7.173750370419604
# J0218+4232_WSRT.P1.328_log10_tnequad:Constant=-6.8507516711893
# J0218+4232_WSRT.P1.328.C_log10_tnequad:Constant=-7.534731266087078
# J0218+4232_WSRT.P1.382_log10_tnequad:Constant=-7.41414729991242
# J0218+4232_WSRT.P1.382.C_log10_tnequad:Constant=-7.586100747081376
# __________________________________________________________________________________________
# J0437-4715_crn                           FourierBasisGP                 1
#
# Basis shape (Ntoas x N basis functions): (5302, 26)
# N selected toas: 5302
#
# params:
# crn_log10_A:Uniform(pmin=-18, pmax=-12)
# crn_gamma:Constant=4.333333333333333
# __________________________________________________________________________________________
# J0437-4715_marginalizing_linear_timing_model TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0437-4715_red_noise                     FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (5302, 60)
# N selected toas: 5302
#
# params:
# J0437-4715_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J0437-4715_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0437-4715_dm_gp                         BasisGP                        2
#
# Basis shape (Ntoas x N basis functions): (5302, 60)
# N selected toas: 5302
#
# params:
# J0437-4715_dm_gp_log10_A:Uniform(pmin=-20, pmax=-11)
# J0437-4715_dm_gp_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0437-4715_measurement_noise             MeasurementNoise               0
#
# params:
# J0437-4715_CPSR2_20CM_efac:Constant=3.2290612139579613
# J0437-4715_CPSR2_40CM_efac:Constant=6.000075065168705
# J0437-4715_CPSR2_50CM_efac:Constant=0.715984169078436
# J0437-4715_PDFB_10CM_efac:Constant=0.6556028503359043
# J0437-4715_PDFB_20CM_efac:Constant=0.9825721735437276
# J0437-4715_PDFB_40CM_efac:Constant=2.0312818880854966
# J0437-4715_PDFB_50CM_efac:Constant=6.255522847690571
# J0437-4715_PKS.cpsr1.20cm_legacy_efac:Constant=0.6444292245992033
# J0437-4715_PKS.cpsr2.20cm_legacy_efac:Constant=0.8733511941348278
# J0437-4715_PKS.fptm.20cm-legacy_efac:Constant=1.908039781736314
# J0437-4715_PKS.s2.20cm-legacy_efac:Constant=0.9971115712763058
# J0437-4715_WBCORR_10CM_efac:Constant=0.3535535791838262
# J0437-4715_WBCORR_20CM_efac:Constant=0.4159929718870762
# __________________________________________________________________________________________
# J0437-4715_tnequad                       TNEquadNoise                   0
#
# params:
# J0437-4715_CPSR2_20CM_log10_tnequad:Constant=-8.312062499643197
# J0437-4715_CPSR2_40CM_log10_tnequad:Constant=-7.143238325090559
# J0437-4715_CPSR2_50CM_log10_tnequad:Constant=-8.638878653967895
# J0437-4715_PDFB_10CM_log10_tnequad:Constant=-7.32213790097949
# J0437-4715_PDFB_20CM_log10_tnequad:Constant=-7.229471179430811
# J0437-4715_PDFB_40CM_log10_tnequad:Constant=-8.238814858233063
# J0437-4715_PDFB_50CM_log10_tnequad:Constant=-7.117925279934146
# J0437-4715_PKS.cpsr1.20cm_legacy_log10_tnequad:Constant=-6.946734903982358
# J0437-4715_PKS.cpsr2.20cm_legacy_log10_tnequad:Constant=-8.725612193837105
# J0437-4715_PKS.fptm.20cm-legacy_log10_tnequad:Constant=-7.388957855179166
# J0437-4715_PKS.s2.20cm-legacy_log10_tnequad:Constant=-8.302563531035613
# J0437-4715_WBCORR_10CM_log10_tnequad:Constant=-6.42757717174192
# J0437-4715_WBCORR_20CM_log10_tnequad:Constant=-8.13575442751912
# __________________________________________________________________________________________
# J0610-2100_crn                           FourierBasisGP                 1
#
# Basis shape (Ntoas x N basis functions): (1034, 26)
# N selected toas: 1034
#
# params:
# crn_log10_A:Uniform(pmin=-18, pmax=-12)
# crn_gamma:Constant=4.333333333333333
# __________________________________________________________________________________________
# J0610-2100_marginalizing_linear_timing_model TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0610-2100_red_noise                     FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (1034, 60)
# N selected toas: 1034
#
# params:
# J0610-2100_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J0610-2100_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0610-2100_dm_gp                         BasisGP                        2
#
# Basis shape (Ntoas x N basis functions): (1034, 60)
# N selected toas: 1034
#
# params:
# J0610-2100_dm_gp_log10_A:Uniform(pmin=-20, pmax=-11)
# J0610-2100_dm_gp_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0610-2100_measurement_noise             MeasurementNoise               0
#
# params:
# J0610-2100_JBO.DFB.1520_efac:Constant=0.9641542227769186
# J0610-2100_NRT.BON.1400_efac:Constant=1.6479102083004218
# J0610-2100_NRT.BON.1600_efac:Constant=1.298875712669822
# __________________________________________________________________________________________
# J0610-2100_tnequad                       TNEquadNoise                   0
#
# params:
# J0610-2100_JBO.DFB.1520_log10_tnequad:Constant=-7.7129089425178
# J0610-2100_NRT.BON.1400_log10_tnequad:Constant=-7.69711587684888
# J0610-2100_NRT.BON.1600_log10_tnequad:Constant=-7.9115611448824765
# __________________________________________________________________________________________
# J0613-0200_crn                           FourierBasisGP                 1
#
# Basis shape (Ntoas x N basis functions): (9322, 26)
# N selected toas: 9322
#
# params:
# crn_log10_A:Uniform(pmin=-18, pmax=-12)
# crn_gamma:Constant=4.333333333333333
# __________________________________________________________________________________________
# J0613-0200_marginalizing_linear_timing_model TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0613-0200_red_noise                     FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (9322, 60)
# N selected toas: 9322
#
# params:
# J0613-0200_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J0613-0200_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0613-0200_dm_gp                         BasisGP                        2
#
# Basis shape (Ntoas x N basis functions): (9322, 60)
# N selected toas: 9322
#
# params:
# J0613-0200_dm_gp_log10_A:Uniform(pmin=-20, pmax=-11)
# J0613-0200_dm_gp_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0613-0200_measurement_noise             MeasurementNoise               0
#
# params:
# J0613-0200_CPSR2_20CM_efac:Constant=0.9990526026644456
# J0613-0200_CPSR2_50CM_efac:Constant=1.6999088098688164
# J0613-0200_EFF.EBPP.1360_efac:Constant=1.0686318230937175
# J0613-0200_EFF.EBPP.1410_efac:Constant=1.123893013450004
# J0613-0200_EFF.EBPP.2639_efac:Constant=1.0327621957013682
# J0613-0200_JBO.DFB.1400_efac:Constant=1.3590437608953723
# J0613-0200_JBO.DFB.1520_efac:Constant=1.0792640382559242
# J0613-0200_NRT.BON.1400_efac:Constant=1.0778803000893573
# J0613-0200_NRT.BON.1600_efac:Constant=1.0167746662995178
# J0613-0200_NRT.BON.2000_efac:Constant=1.192864008813911
# J0613-0200_PDFB_10CM_efac:Constant=1.1099481886363973
# J0613-0200_PDFB_20CM_efac:Constant=1.0647367270212134
# J0613-0200_PDFB_40CM_efac:Constant=1.2213673105000562
# J0613-0200_PKS.AFB.20cm_legacy_efac:Constant=0.8961097920734187
# J0613-0200_PKS.cpsr2.50cm_legacy_efac:Constant=0.3207383192913973
# J0613-0200_PKS.fptm.20cm-legacy_efac:Constant=1.1278838564208946
# J0613-0200_Rcvr1_2_GASP_efac:Constant=1.0879137222600277
# J0613-0200_Rcvr1_2_GUPPI_efac:Constant=1.085943825553402
# J0613-0200_Rcvr_800_GASP_efac:Constant=1.0918817095949436
# J0613-0200_Rcvr_800_GUPPI_efac:Constant=1.1976736067236975
# J0613-0200_WBCORR_10CM_efac:Constant=2.0635323024272343
# J0613-0200_WSRT.P1.1380_efac:Constant=0.9976965163671994
# J0613-0200_WSRT.P1.1380.C_efac:Constant=1.0818280017977853
# J0613-0200_WSRT.P1.328_efac:Constant=1.200376030250487
# J0613-0200_WSRT.P1.328.C_efac:Constant=1.640960722949359
# J0613-0200_WSRT.P1.382_efac:Constant=0.9428376562057674
# J0613-0200_WSRT.P1.382.C_efac:Constant=1.0032787738411562
# __________________________________________________________________________________________
# J0613-0200_tnequad                       TNEquadNoise                   0
#
# params:
# J0613-0200_CPSR2_20CM_log10_tnequad:Constant=-8.0989739210902
# J0613-0200_CPSR2_50CM_log10_tnequad:Constant=-7.782658566452038
# J0613-0200_EFF.EBPP.1360_log10_tnequad:Constant=-7.9255963789880814
# J0613-0200_EFF.EBPP.1410_log10_tnequad:Constant=-7.887113521841751
# J0613-0200_EFF.EBPP.2639_log10_tnequad:Constant=-7.617334763288597
# J0613-0200_JBO.DFB.1400_log10_tnequad:Constant=-7.763631119682452
# J0613-0200_JBO.DFB.1520_log10_tnequad:Constant=-7.778891693898806
# J0613-0200_NRT.BON.1400_log10_tnequad:Constant=-8.028043057476285
# J0613-0200_NRT.BON.1600_log10_tnequad:Constant=-8.192895579916456
# J0613-0200_NRT.BON.2000_log10_tnequad:Constant=-7.958831049941765
# J0613-0200_PDFB_10CM_log10_tnequad:Constant=-7.656619232964946
# J0613-0200_PDFB_20CM_log10_tnequad:Constant=-8.203757817089432
# J0613-0200_PDFB_40CM_log10_tnequad:Constant=-7.92784750084169
# J0613-0200_PKS.AFB.20cm_legacy_log10_tnequad:Constant=-7.877536756313509
# J0613-0200_PKS.cpsr2.50cm_legacy_log10_tnequad:Constant=-7.605365573958282
# J0613-0200_PKS.fptm.20cm-legacy_log10_tnequad:Constant=-7.817928956198638
# J0613-0200_Rcvr1_2_GASP_log10_tnequad:Constant=-8.261744436404165
# J0613-0200_Rcvr1_2_GUPPI_log10_tnequad:Constant=-8.385742214224988
# J0613-0200_Rcvr_800_GASP_log10_tnequad:Constant=-8.315347204047601
# J0613-0200_Rcvr_800_GUPPI_log10_tnequad:Constant=-6.508517096441438
# J0613-0200_WBCORR_10CM_log10_tnequad:Constant=-7.652855099639509
# J0613-0200_WSRT.P1.1380_log10_tnequad:Constant=-8.00228850312434
# J0613-0200_WSRT.P1.1380.C_log10_tnequad:Constant=-7.831440632094263
# J0613-0200_WSRT.P1.328_log10_tnequad:Constant=-7.384295170290664
# J0613-0200_WSRT.P1.328.C_log10_tnequad:Constant=-7.4532055268668245
# J0613-0200_WSRT.P1.382_log10_tnequad:Constant=-7.5528686725886605
# J0613-0200_WSRT.P1.382.C_log10_tnequad:Constant=-6.7621078965198915
# __________________________________________________________________________________________
# J0613-0200_ecorr_fast-sherman-morrison   EcorrKernelNoise               0
#
# params:
# J0613-0200_Rcvr1_2_GASP_log10_ecorr:Constant=-8.180510638874415
# J0613-0200_Rcvr1_2_GUPPI_log10_ecorr:Constant=-8.523962840526593
# J0613-0200_Rcvr_800_GASP_log10_ecorr:Constant=-6.551949630040972
# J0613-0200_Rcvr_800_GUPPI_log10_ecorr:Constant=-6.795464371978297
# __________________________________________________________________________________________
# J0621+1002_crn                           FourierBasisGP                 1
#
# Basis shape (Ntoas x N basis functions): (682, 26)
# N selected toas: 682
#
# params:
# crn_log10_A:Uniform(pmin=-18, pmax=-12)
# crn_gamma:Constant=4.333333333333333
# __________________________________________________________________________________________
# J0621+1002_marginalizing_linear_timing_model TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0621+1002_red_noise                     FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (682, 60)
# N selected toas: 682
#
# params:
# J0621+1002_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J0621+1002_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0621+1002_dm_gp                         BasisGP                        2
#
# Basis shape (Ntoas x N basis functions): (682, 60)
# N selected toas: 682
#
# params:
# J0621+1002_dm_gp_log10_A:Uniform(pmin=-20, pmax=-11)
# J0621+1002_dm_gp_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0621+1002_measurement_noise             MeasurementNoise               0
#
# params:
# J0621+1002_EFF.EBPP.1360_efac:Constant=0.786497859192605
# J0621+1002_EFF.EBPP.1410_efac:Constant=0.6283621743880112
# J0621+1002_EFF.EBPP.2639_efac:Constant=0.7491973989724956
# J0621+1002_JBO.DFB.1400_efac:Constant=0.9919049818052157
# J0621+1002_JBO.DFB.1520_efac:Constant=1.0912383029917716
# J0621+1002_NRT.BON.1400_efac:Constant=1.3654540798440986
# J0621+1002_NRT.BON.1600_efac:Constant=1.2117048099609702
# J0621+1002_NRT.BON.2000_efac:Constant=0.8790059296436121
# J0621+1002_WSRT.P1.1380.C_efac:Constant=1.1861762906397695
# J0621+1002_WSRT.P1.323.C_efac:Constant=2.1114681027090434
# J0621+1002_WSRT.P1.367.C_efac:Constant=1.6560481291117797
# __________________________________________________________________________________________
# J0621+1002_tnequad                       TNEquadNoise                   0
#
# params:
# J0621+1002_EFF.EBPP.1360_log10_tnequad:Constant=-7.560081398230025
# J0621+1002_EFF.EBPP.1410_log10_tnequad:Constant=-7.223732427214496
# J0621+1002_EFF.EBPP.2639_log10_tnequad:Constant=-4.440423413654555
# J0621+1002_JBO.DFB.1400_log10_tnequad:Constant=-7.353234350553075
# J0621+1002_JBO.DFB.1520_log10_tnequad:Constant=-7.638725046891599
# J0621+1002_NRT.BON.1400_log10_tnequad:Constant=-7.673021356613772
# J0621+1002_NRT.BON.1600_log10_tnequad:Constant=-7.534439818397022
# J0621+1002_NRT.BON.2000_log10_tnequad:Constant=-7.528672983662842
# J0621+1002_WSRT.P1.1380.C_log10_tnequad:Constant=-7.669436973944201
# J0621+1002_WSRT.P1.323.C_log10_tnequad:Constant=-7.158755833782374
# J0621+1002_WSRT.P1.367.C_log10_tnequad:Constant=-7.046913791752295
# __________________________________________________________________________________________
# J0711-6830_crn                           FourierBasisGP                 1
#
# Basis shape (Ntoas x N basis functions): (507, 26)
# N selected toas: 507
#
# params:
# crn_log10_A:Uniform(pmin=-18, pmax=-12)
# crn_gamma:Constant=4.333333333333333
# __________________________________________________________________________________________
# J0711-6830_marginalizing_linear_timing_model TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0711-6830_red_noise                     FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (507, 60)
# N selected toas: 507
#
# params:
# J0711-6830_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J0711-6830_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0711-6830_dm_gp                         BasisGP                        2
#
# Basis shape (Ntoas x N basis functions): (507, 60)
# N selected toas: 507
#
# params:
# J0711-6830_dm_gp_log10_A:Uniform(pmin=-20, pmax=-11)
# J0711-6830_dm_gp_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0711-6830_measurement_noise             MeasurementNoise               0
#
# params:
# J0711-6830_CPSR2_20CM_efac:Constant=1.0153776516103803
# J0711-6830_CPSR2_40CM_efac:Constant=0.5940183572369302
# J0711-6830_CPSR2_50CM_efac:Constant=1.2438301069657745
# J0711-6830_PDFB_10CM_efac:Constant=0.9654069178823529
# J0711-6830_PDFB_20CM_efac:Constant=0.9800083072741999
# J0711-6830_PDFB_40CM_efac:Constant=1.2494082959677828
# J0711-6830_PKS.AFB.20cm_legacy_efac:Constant=2.900556883350094
# J0711-6830_PKS.cpsr2.20cm_legacy_efac:Constant=1.993180656249257
# J0711-6830_PKS.fptm.20cm-legacy_efac:Constant=2.1459693262645025
# J0711-6830_WBCORR_10CM_efac:Constant=0.9885090929655896
# __________________________________________________________________________________________
# J0711-6830_tnequad                       TNEquadNoise                   0
#
# params:
# J0711-6830_CPSR2_20CM_log10_tnequad:Constant=-8.303330903184671
# J0711-6830_CPSR2_40CM_log10_tnequad:Constant=-7.4152961234121655
# J0711-6830_CPSR2_50CM_log10_tnequad:Constant=-7.542204098866569
# J0711-6830_PDFB_10CM_log10_tnequad:Constant=-7.948409733962268
# J0711-6830_PDFB_20CM_log10_tnequad:Constant=-6.5106992066349285
# J0711-6830_PDFB_40CM_log10_tnequad:Constant=-7.894251676512292
# J0711-6830_PKS.AFB.20cm_legacy_log10_tnequad:Constant=-7.4122060681287385
# J0711-6830_PKS.cpsr2.20cm_legacy_log10_tnequad:Constant=-7.8936157860960385
# J0711-6830_PKS.fptm.20cm-legacy_log10_tnequad:Constant=-7.8579688722267695
# J0711-6830_WBCORR_10CM_log10_tnequad:Constant=-7.778161703469346
# __________________________________________________________________________________________
# J0751+1807_crn                           FourierBasisGP                 1
#
# Basis shape (Ntoas x N basis functions): (1491, 26)
# N selected toas: 1491
#
# params:
# crn_log10_A:Uniform(pmin=-18, pmax=-12)
# crn_gamma:Constant=4.333333333333333
# __________________________________________________________________________________________
# J0751+1807_marginalizing_linear_timing_model TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0751+1807_red_noise                     FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (1491, 60)
# N selected toas: 1491
#
# params:
# J0751+1807_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J0751+1807_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0751+1807_dm_gp                         BasisGP                        2
#
# Basis shape (Ntoas x N basis functions): (1491, 60)
# N selected toas: 1491
#
# params:
# J0751+1807_dm_gp_log10_A:Uniform(pmin=-20, pmax=-11)
# J0751+1807_dm_gp_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0751+1807_measurement_noise             MeasurementNoise               0
#
# params:
# J0751+1807_EFF.EBPP.1360_efac:Constant=1.0154674522535574
# J0751+1807_EFF.EBPP.1410_efac:Constant=0.9848595211104691
# J0751+1807_EFF.EBPP.2639_efac:Constant=1.0763912855911477
# J0751+1807_JBO.DFB.1400_efac:Constant=1.088090037548855
# J0751+1807_JBO.DFB.1520_efac:Constant=0.9881681863574714
# J0751+1807_NRT.BON.1400_efac:Constant=1.212751465455424
# J0751+1807_NRT.BON.1600_efac:Constant=1.1067759227215974
# J0751+1807_NRT.BON.2000_efac:Constant=0.776180905780587
# J0751+1807_WSRT.P1.1380.C_efac:Constant=1.3700593475898701
# __________________________________________________________________________________________
# J0751+1807_tnequad                       TNEquadNoise                   0
#
# params:
# J0751+1807_EFF.EBPP.1360_log10_tnequad:Constant=-5.332364005844169
# J0751+1807_EFF.EBPP.1410_log10_tnequad:Constant=-5.745666271496923
# J0751+1807_EFF.EBPP.2639_log10_tnequad:Constant=-5.339129255083902
# J0751+1807_JBO.DFB.1400_log10_tnequad:Constant=-7.872322693740404
# J0751+1807_JBO.DFB.1520_log10_tnequad:Constant=-7.893712140310059
# J0751+1807_NRT.BON.1400_log10_tnequad:Constant=-6.08724754833447
# J0751+1807_NRT.BON.1600_log10_tnequad:Constant=-8.086968926546273
# J0751+1807_NRT.BON.2000_log10_tnequad:Constant=-5.575030276443315
# J0751+1807_WSRT.P1.1380.C_log10_tnequad:Constant=-7.790114125174388
# __________________________________________________________________________________________
# J0900-3144_crn                           FourierBasisGP                 1
#
# Basis shape (Ntoas x N basis functions): (875, 26)
# N selected toas: 875
#
# params:
# crn_log10_A:Uniform(pmin=-18, pmax=-12)
# crn_gamma:Constant=4.333333333333333
# __________________________________________________________________________________________
# J0900-3144_marginalizing_linear_timing_model TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J0900-3144_red_noise                     FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (875, 60)
# N selected toas: 875
#
# params:
# J0900-3144_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J0900-3144_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0900-3144_dm_gp                         BasisGP                        2
#
# Basis shape (Ntoas x N basis functions): (875, 60)
# N selected toas: 875
#
# params:
# J0900-3144_dm_gp_log10_A:Uniform(pmin=-20, pmax=-11)
# J0900-3144_dm_gp_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J0900-3144_measurement_noise             MeasurementNoise               0
#
# params:
# J0900-3144_JBO.DFB.1400_efac:Constant=0.8685206821194367
# J0900-3144_JBO.DFB.1520_efac:Constant=1.0105151417045493
# J0900-3144_NRT.BON.1400_efac:Constant=1.0620744854509447
# J0900-3144_NRT.BON.1600_efac:Constant=1.220085677646559
# J0900-3144_NRT.BON.2000_efac:Constant=1.1746224170453043
# __________________________________________________________________________________________
# J0900-3144_tnequad                       TNEquadNoise                   0
#
# params:
# J0900-3144_JBO.DFB.1400_log10_tnequad:Constant=-7.436194199714588
# J0900-3144_JBO.DFB.1520_log10_tnequad:Constant=-7.851440793505474
# J0900-3144_NRT.BON.1400_log10_tnequad:Constant=-7.959753745118478
# J0900-3144_NRT.BON.1600_log10_tnequad:Constant=-6.383780833216171
# J0900-3144_NRT.BON.2000_log10_tnequad:Constant=-7.2486732717153926
# __________________________________________________________________________________________
# J1012+5307_crn                           FourierBasisGP                 1
#
# Basis shape (Ntoas x N basis functions): (13056, 26)
# N selected toas: 13056
#
# params:
# crn_log10_A:Uniform(pmin=-18, pmax=-12)
# crn_gamma:Constant=4.333333333333333
# __________________________________________________________________________________________
# J1012+5307_marginalizing_linear_timing_model TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J1012+5307_red_noise                     FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (13056, 60)
# N selected toas: 13056
#
# params:
# J1012+5307_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J1012+5307_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1012+5307_dm_gp                         BasisGP                        2
#
# Basis shape (Ntoas x N basis functions): (13056, 60)
# N selected toas: 13056
#
# params:
# J1012+5307_dm_gp_log10_A:Uniform(pmin=-20, pmax=-11)
# J1012+5307_dm_gp_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1012+5307_measurement_noise             MeasurementNoise               0
#
# params:
# J1012+5307_EFF.EBPP.1360_efac:Constant=0.614712605286877
# J1012+5307_EFF.EBPP.1410_efac:Constant=0.9858315547212431
# J1012+5307_EFF.EBPP.2639_efac:Constant=1.012297189773692
# J1012+5307_JBO.DFB.1400_efac:Constant=1.0708351812344714
# J1012+5307_JBO.DFB.1520_efac:Constant=1.0204483769103245
# J1012+5307_NRT.BON.1400_efac:Constant=1.2477324086876358
# J1012+5307_NRT.BON.1600_efac:Constant=1.2328841008841476
# J1012+5307_NRT.BON.2000_efac:Constant=1.108888917652214
# J1012+5307_Rcvr1_2_GASP_efac:Constant=1.0641420942156123
# J1012+5307_Rcvr1_2_GUPPI_efac:Constant=1.082053942034094
# J1012+5307_Rcvr_800_GASP_efac:Constant=1.1195940785160978
# J1012+5307_Rcvr_800_GUPPI_efac:Constant=1.1739088703583054
# J1012+5307_WSRT.P1.1380.1_efac:Constant=1.1523290538386368
# J1012+5307_WSRT.P1.1380.2_efac:Constant=0.973984502526801
# J1012+5307_WSRT.P1.1380.2.C_efac:Constant=0.9915119631468814
# J1012+5307_WSRT.P1.328_efac:Constant=1.2738579236670668
# J1012+5307_WSRT.P1.328.C_efac:Constant=1.29016075891679
# J1012+5307_WSRT.P1.382_efac:Constant=0.9834578944743545
# J1012+5307_WSRT.P1.382.C_efac:Constant=0.933432054170587
# __________________________________________________________________________________________
# J1012+5307_tnequad                       TNEquadNoise                   0
#
# params:
# J1012+5307_EFF.EBPP.1360_log10_tnequad:Constant=-5.472219542105842
# J1012+5307_EFF.EBPP.1410_log10_tnequad:Constant=-6.486189661503714
# J1012+5307_EFF.EBPP.2639_log10_tnequad:Constant=-7.8517178935162075
# J1012+5307_JBO.DFB.1400_log10_tnequad:Constant=-8.000943153224128
# J1012+5307_JBO.DFB.1520_log10_tnequad:Constant=-5.998804238101281
# J1012+5307_NRT.BON.1400_log10_tnequad:Constant=-6.816659650178497
# J1012+5307_NRT.BON.1600_log10_tnequad:Constant=-6.05391724322667
# J1012+5307_NRT.BON.2000_log10_tnequad:Constant=-7.764728786681073
# J1012+5307_Rcvr1_2_GASP_log10_tnequad:Constant=-8.023797488948006
# J1012+5307_Rcvr1_2_GUPPI_log10_tnequad:Constant=-6.40541882674987
# J1012+5307_Rcvr_800_GASP_log10_tnequad:Constant=-7.8781337806904785
# J1012+5307_Rcvr_800_GUPPI_log10_tnequad:Constant=-6.308362633631808
# J1012+5307_WSRT.P1.1380.1_log10_tnequad:Constant=-7.461930279573558
# J1012+5307_WSRT.P1.1380.2_log10_tnequad:Constant=-8.01375234812847
# J1012+5307_WSRT.P1.1380.2.C_log10_tnequad:Constant=-8.130476575911114
# J1012+5307_WSRT.P1.328_log10_tnequad:Constant=-7.63658672312569
# J1012+5307_WSRT.P1.328.C_log10_tnequad:Constant=-7.659004607466129
# J1012+5307_WSRT.P1.382_log10_tnequad:Constant=-7.538882510157623
# J1012+5307_WSRT.P1.382.C_log10_tnequad:Constant=-5.703201055551062
# __________________________________________________________________________________________
# J1012+5307_ecorr_fast-sherman-morrison   EcorrKernelNoise               0
#
# params:
# J1012+5307_Rcvr1_2_GASP_log10_ecorr:Constant=-6.427872167002646
# J1012+5307_Rcvr1_2_GUPPI_log10_ecorr:Constant=-6.25129733404697
# J1012+5307_Rcvr_800_GASP_log10_ecorr:Constant=-8.068081137683215
# J1012+5307_Rcvr_800_GUPPI_log10_ecorr:Constant=-6.278688950988679
# __________________________________________________________________________________________
# J1022+1001_crn                           FourierBasisGP                 1
#
# Basis shape (Ntoas x N basis functions): (1399, 26)
# N selected toas: 1399
#
# params:
# crn_log10_A:Uniform(pmin=-18, pmax=-12)
# crn_gamma:Constant=4.333333333333333
# __________________________________________________________________________________________
# J1022+1001_marginalizing_linear_timing_model TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J1022+1001_red_noise                     FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (1399, 60)
# N selected toas: 1399
#
# params:
# J1022+1001_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J1022+1001_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1022+1001_dm_gp                         BasisGP                        2
#
# Basis shape (Ntoas x N basis functions): (1399, 60)
# N selected toas: 1399
#
# params:
# J1022+1001_dm_gp_log10_A:Uniform(pmin=-20, pmax=-11)
# J1022+1001_dm_gp_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J1022+1001_measurement_noise             MeasurementNoise               0
#
# ...
# J2145-0750_JBO.DFB.1400_efac:Constant=1.310906039284168
# J2145-0750_JBO.DFB.1520_efac:Constant=1.0438027330515371
# J2145-0750_NRT.BON.1400_efac:Constant=1.195103499131813
# J2145-0750_NRT.BON.1600_efac:Constant=1.2780453456358591
# J2145-0750_NRT.BON.2000_efac:Constant=1.0923380904535056
# J2145-0750_PDFB_10CM_efac:Constant=1.1391771488909466
# J2145-0750_PDFB_20CM_efac:Constant=0.8726963939757095
# J2145-0750_PDFB_40CM_efac:Constant=0.9367249058165859
# J2145-0750_PKS.AFB.20cm_legacy_efac:Constant=1.2194748018596315
# J2145-0750_PKS.cpsr2.20cm_legacy_efac:Constant=1.6739921805254838
# J2145-0750_PKS.fptm.20cm-legacy_efac:Constant=1.503609046409038
# J2145-0750_Rcvr1_2_GASP_efac:Constant=1.0048700981554086
# J2145-0750_Rcvr1_2_GUPPI_efac:Constant=1.0978954507121577
# J2145-0750_Rcvr_800_GASP_efac:Constant=1.4947351184896585
# J2145-0750_Rcvr_800_GUPPI_efac:Constant=1.1244881084820446
# J2145-0750_WBCORR_10CM_efac:Constant=1.6956128042877014
# J2145-0750_WBCORR_20CM_efac:Constant=3.056560548193175
# J2145-0750_WSRT.P1.1380.C_efac:Constant=1.0931793413557618
# J2145-0750_WSRT.P1.2273.C_efac:Constant=3.3168462563130467
# J2145-0750_WSRT.P1.323.C_efac:Constant=1.8943505623771613
# J2145-0750_WSRT.P1.367.C_efac:Constant=1.4512753475755429
# __________________________________________________________________________________________
# J2145-0750_tnequad                       TNEquadNoise                   0
#
# params:
# J2145-0750_CPSR2_20CM_log10_tnequad:Constant=-6.037516319050601
# J2145-0750_CPSR2_50CM_log10_tnequad:Constant=-5.655051154176572
# J2145-0750_EFF.EBPP.1360_log10_tnequad:Constant=-8.115175611796785
# J2145-0750_EFF.EBPP.1410_log10_tnequad:Constant=-5.871045499466678
# J2145-0750_EFF.EBPP.2639_log10_tnequad:Constant=-6.23000270681759
# J2145-0750_JBO.DFB.1400_log10_tnequad:Constant=-7.512179735608023
# J2145-0750_JBO.DFB.1520_log10_tnequad:Constant=-6.3449341243998605
# J2145-0750_NRT.BON.1400_log10_tnequad:Constant=-6.27295935778286
# J2145-0750_NRT.BON.1600_log10_tnequad:Constant=-7.855359309618975
# J2145-0750_NRT.BON.2000_log10_tnequad:Constant=-5.842906658766769
# J2145-0750_PDFB_10CM_log10_tnequad:Constant=-7.877119087533348
# J2145-0750_PDFB_20CM_log10_tnequad:Constant=-6.149623976926298
# J2145-0750_PDFB_40CM_log10_tnequad:Constant=-7.698492938474525
# J2145-0750_PKS.AFB.20cm_legacy_log10_tnequad:Constant=-7.825413671992568
# J2145-0750_PKS.cpsr2.20cm_legacy_log10_tnequad:Constant=-8.12992190180801
# J2145-0750_PKS.fptm.20cm-legacy_log10_tnequad:Constant=-8.153418753713542
# J2145-0750_Rcvr1_2_GASP_log10_tnequad:Constant=-5.719367549578205
# J2145-0750_Rcvr1_2_GUPPI_log10_tnequad:Constant=-6.284865664893189
# J2145-0750_Rcvr_800_GASP_log10_tnequad:Constant=-6.908335617076674
# J2145-0750_Rcvr_800_GUPPI_log10_tnequad:Constant=-6.318904398027962
# J2145-0750_WBCORR_10CM_log10_tnequad:Constant=-7.7139766778871905
# J2145-0750_WBCORR_20CM_log10_tnequad:Constant=-6.348032710741417
# J2145-0750_WSRT.P1.1380.C_log10_tnequad:Constant=-7.981732561145028
# J2145-0750_WSRT.P1.2273.C_log10_tnequad:Constant=-7.180097379617118
# J2145-0750_WSRT.P1.323.C_log10_tnequad:Constant=-7.087970852219255
# J2145-0750_WSRT.P1.367.C_log10_tnequad:Constant=-5.527465808554715
# __________________________________________________________________________________________
# J2145-0750_ecorr_fast-sherman-morrison   EcorrKernelNoise               0
#
# params:
# J2145-0750_Rcvr1_2_GASP_log10_ecorr:Constant=-5.742989909254695
# J2145-0750_Rcvr1_2_GUPPI_log10_ecorr:Constant=-6.370029568524956
# J2145-0750_Rcvr_800_GASP_log10_ecorr:Constant=-5.740845262393644
# J2145-0750_Rcvr_800_GUPPI_log10_ecorr:Constant=-5.818118341582993
# __________________________________________________________________________________________
# J2229+2643_crn                           FourierBasisGP                 1
#
# Basis shape (Ntoas x N basis functions): (316, 26)
# N selected toas: 316
#
# params:
# crn_log10_A:Uniform(pmin=-18, pmax=-12)
# crn_gamma:Constant=4.333333333333333
# __________________________________________________________________________________________
# J2229+2643_marginalizing_linear_timing_model TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J2229+2643_red_noise                     FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (316, 60)
# N selected toas: 316
#
# params:
# J2229+2643_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J2229+2643_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2229+2643_dm_gp                         BasisGP                        2
#
# Basis shape (Ntoas x N basis functions): (316, 60)
# N selected toas: 316
#
# params:
# J2229+2643_dm_gp_log10_A:Uniform(pmin=-20, pmax=-11)
# J2229+2643_dm_gp_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2229+2643_measurement_noise             MeasurementNoise               0
#
# params:
# J2229+2643_EFF.EBPP.1360_efac:Constant=1.4753903198360236
# J2229+2643_EFF.EBPP.2639_efac:Constant=0.5079303291159096
# J2229+2643_JBO.DFB.1400_efac:Constant=2.070467290383407
# J2229+2643_JBO.DFB.1520_efac:Constant=1.0721836160860214
# J2229+2643_NRT.BON.1400_efac:Constant=1.7535174445199728
# J2229+2643_NRT.BON.1600_efac:Constant=1.5109508669200633
# __________________________________________________________________________________________
# J2229+2643_tnequad                       TNEquadNoise                   0
#
# params:
# J2229+2643_EFF.EBPP.1360_log10_tnequad:Constant=-7.5834997570039615
# J2229+2643_EFF.EBPP.2639_log10_tnequad:Constant=-5.263438825590212
# J2229+2643_JBO.DFB.1400_log10_tnequad:Constant=-7.423835891012034
# J2229+2643_JBO.DFB.1520_log10_tnequad:Constant=-7.6058751758721055
# J2229+2643_NRT.BON.1400_log10_tnequad:Constant=-8.07707148449473
# J2229+2643_NRT.BON.1600_log10_tnequad:Constant=-7.900166344709138
# __________________________________________________________________________________________
# J2317+1439_crn                           FourierBasisGP                 1
#
# Basis shape (Ntoas x N basis functions): (3175, 26)
# N selected toas: 3175
#
# params:
# crn_log10_A:Uniform(pmin=-18, pmax=-12)
# crn_gamma:Constant=4.333333333333333
# __________________________________________________________________________________________
# J2317+1439_marginalizing_linear_timing_model TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J2317+1439_red_noise                     FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (3175, 60)
# N selected toas: 3175
#
# params:
# J2317+1439_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J2317+1439_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2317+1439_dm_gp                         BasisGP                        2
#
# Basis shape (Ntoas x N basis functions): (3175, 60)
# N selected toas: 3175
#
# params:
# J2317+1439_dm_gp_log10_A:Uniform(pmin=-20, pmax=-11)
# J2317+1439_dm_gp_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2317+1439_measurement_noise             MeasurementNoise               0
#
# params:
# J2317+1439_327_ASP_efac:Constant=1.0614032875511354
# J2317+1439_327_PUPPI_efac:Constant=1.146509950328292
# J2317+1439_430_ASP_efac:Constant=1.1654782676519402
# J2317+1439_430_PUPPI_efac:Constant=1.0390885815046165
# J2317+1439_EFF.EBPP.1360_efac:Constant=1.919434712892923
# J2317+1439_EFF.EBPP.1410_efac:Constant=1.5436165849474306
# J2317+1439_EFF.EBPP.2639_efac:Constant=1.10336350243898
# J2317+1439_JBO.DFB.1400_efac:Constant=1.3510354678808962
# J2317+1439_JBO.DFB.1520_efac:Constant=1.0954928960373396
# J2317+1439_L-wide_PUPPI_efac:Constant=0.9526263367363631
# J2317+1439_NRT.BON.1400_efac:Constant=1.4179103446679118
# J2317+1439_NRT.BON.1600_efac:Constant=1.493442755408363
# J2317+1439_WSRT.P1.1380.C_efac:Constant=1.4749179458096107
# __________________________________________________________________________________________
# J2317+1439_tnequad                       TNEquadNoise                   0
#
# params:
# J2317+1439_327_ASP_log10_tnequad:Constant=-6.405306511630214
# J2317+1439_327_PUPPI_log10_tnequad:Constant=-6.365137708468269
# J2317+1439_430_ASP_log10_tnequad:Constant=-6.753266532342159
# J2317+1439_430_PUPPI_log10_tnequad:Constant=-6.406681557911251
# J2317+1439_EFF.EBPP.1360_log10_tnequad:Constant=-7.9788193494721495
# J2317+1439_EFF.EBPP.1410_log10_tnequad:Constant=-7.646109207080147
# J2317+1439_EFF.EBPP.2639_log10_tnequad:Constant=-7.75600319081746
# J2317+1439_JBO.DFB.1400_log10_tnequad:Constant=-7.532951952500445
# J2317+1439_JBO.DFB.1520_log10_tnequad:Constant=-8.059837708575493
# J2317+1439_L-wide_PUPPI_log10_tnequad:Constant=-6.543831528909868
# J2317+1439_NRT.BON.1400_log10_tnequad:Constant=-8.178348609124637
# J2317+1439_NRT.BON.1600_log10_tnequad:Constant=-8.17546468060141
# J2317+1439_WSRT.P1.1380.C_log10_tnequad:Constant=-7.6656267350197815
# __________________________________________________________________________________________
# J2317+1439_ecorr_fast-sherman-morrison   EcorrKernelNoise               0
#
# params:
# J2317+1439_327_ASP_log10_ecorr:Constant=-5.852955174393413
# J2317+1439_327_PUPPI_log10_ecorr:Constant=-5.796885889356396
# J2317+1439_430_ASP_log10_ecorr:Constant=-6.1122646755700805
# J2317+1439_430_PUPPI_log10_ecorr:Constant=-5.9789970596282505
# J2317+1439_L-wide_PUPPI_log10_ecorr:Constant=-7.171507726973681
# __________________________________________________________________________________________
# J2322+2057_crn                           FourierBasisGP                 1
#
# Basis shape (Ntoas x N basis functions): (229, 26)
# N selected toas: 229
#
# params:
# crn_log10_A:Uniform(pmin=-18, pmax=-12)
# crn_gamma:Constant=4.333333333333333
# __________________________________________________________________________________________
# J2322+2057_marginalizing_linear_timing_model TimingModel                    0
#
# params:
# __________________________________________________________________________________________
# J2322+2057_red_noise                     FourierBasisGP                 2
#
# Basis shape (Ntoas x N basis functions): (229, 60)
# N selected toas: 229
#
# params:
# J2322+2057_red_noise_log10_A:Uniform(pmin=-20, pmax=-11)
# J2322+2057_red_noise_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2322+2057_dm_gp                         BasisGP                        2
#
# Basis shape (Ntoas x N basis functions): (229, 60)
# N selected toas: 229
#
# params:
# J2322+2057_dm_gp_log10_A:Uniform(pmin=-20, pmax=-11)
# J2322+2057_dm_gp_gamma:Uniform(pmin=0, pmax=7)
# __________________________________________________________________________________________
# J2322+2057_measurement_noise             MeasurementNoise               0
#
# params:
# J2322+2057_JBO.DFB.1400_efac:Constant=0.8508240292022311
# J2322+2057_JBO.DFB.1520_efac:Constant=1.4308984507343716
# J2322+2057_NRT.BON.1400_efac:Constant=1.7185657998101889
# J2322+2057_NRT.BON.1600_efac:Constant=1.1972647348897671
# __________________________________________________________________________________________
# J2322+2057_tnequad                       TNEquadNoise                   0
#
# params:
# J2322+2057_JBO.DFB.1400_log10_tnequad:Constant=-7.223524148608675
# J2322+2057_JBO.DFB.1520_log10_tnequad:Constant=-7.771482100158469
# J2322+2057_NRT.BON.1400_log10_tnequad:Constant=-7.938735317337827
# J2322+2057_NRT.BON.1600_log10_tnequad:Constant=-7.429024169082759
# __________________________________________________________________________________________
# ==========================================================================================
# Total params: 1548
# Varying params: 216
# Common params: 53
# Fixed params: 1332
# Number of pulsars: 53

# %%
def likelihood_eval(pta):
    random_sample = {p.name:p.sample() for p in pta.params}
    return pta.get_lnlikelihood(random_sample)

# %%
# %timeit likelihood_eval(pta)
# Out:
# 18.9 ms ± 553 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# set groups for adaptive metropolis
gr = get_parameter_groups_CAW_target(pta)
for group in gr:
    print(np.array(pta.param_names)[np.array(group)])
# Out:
# test
# ['J0030+0451_dm_gp_gamma' 'J0030+0451_dm_gp_log10_A'
#  'J0030+0451_red_noise_gamma' 'J0030+0451_red_noise_log10_A'
#  'J0034-0534_dm_gp_gamma' 'J0034-0534_dm_gp_log10_A'
#  'J0034-0534_red_noise_gamma' 'J0034-0534_red_noise_log10_A'
#  'J0218+4232_dm_gp_gamma' 'J0218+4232_dm_gp_log10_A'
#  'J0218+4232_red_noise_gamma' 'J0218+4232_red_noise_log10_A'
#  'J0437-4715_dm_gp_gamma' 'J0437-4715_dm_gp_log10_A'
#  'J0437-4715_red_noise_gamma' 'J0437-4715_red_noise_log10_A'
#  'J0610-2100_dm_gp_gamma' 'J0610-2100_dm_gp_log10_A'
#  'J0610-2100_red_noise_gamma' 'J0610-2100_red_noise_log10_A'
#  'J0613-0200_dm_gp_gamma' 'J0613-0200_dm_gp_log10_A'
#  'J0613-0200_red_noise_gamma' 'J0613-0200_red_noise_log10_A'
#  'J0621+1002_dm_gp_gamma' 'J0621+1002_dm_gp_log10_A'
#  'J0621+1002_red_noise_gamma' 'J0621+1002_red_noise_log10_A'
#  'J0711-6830_dm_gp_gamma' 'J0711-6830_dm_gp_log10_A'
#  'J0711-6830_red_noise_gamma' 'J0711-6830_red_noise_log10_A'
#  'J0751+1807_dm_gp_gamma' 'J0751+1807_dm_gp_log10_A'
#  'J0751+1807_red_noise_gamma' 'J0751+1807_red_noise_log10_A'
#  'J0900-3144_dm_gp_gamma' 'J0900-3144_dm_gp_log10_A'
#  'J0900-3144_red_noise_gamma' 'J0900-3144_red_noise_log10_A'
#  'J1012+5307_dm_gp_gamma' 'J1012+5307_dm_gp_log10_A'
#  'J1012+5307_red_noise_gamma' 'J1012+5307_red_noise_log10_A'
#  'J1022+1001_dm_gp_gamma' 'J1022+1001_dm_gp_log10_A'
#  'J1022+1001_red_noise_gamma' 'J1022+1001_red_noise_log10_A'
#  'J1024-0719_dm_gp_gamma' 'J1024-0719_dm_gp_log10_A'
#  'J1024-0719_red_noise_gamma' 'J1024-0719_red_noise_log10_A'
#  'J1045-4509_dm_gp_gamma' 'J1045-4509_dm_gp_log10_A'
#  'J1045-4509_red_noise_gamma' 'J1045-4509_red_noise_log10_A'
#  'J1455-3330_dm_gp_gamma' 'J1455-3330_dm_gp_log10_A'
#  'J1455-3330_red_noise_gamma' 'J1455-3330_red_noise_log10_A'
#  'J1600-3053_dm_gp_gamma' 'J1600-3053_dm_gp_log10_A'
#  'J1600-3053_red_noise_gamma' 'J1600-3053_red_noise_log10_A'
#  'J1603-7202_dm_gp_gamma' 'J1603-7202_dm_gp_log10_A'
#  'J1603-7202_red_noise_gamma' 'J1603-7202_red_noise_log10_A'
#  'J1614-2230_dm_gp_gamma' 'J1614-2230_dm_gp_log10_A'
#  'J1614-2230_red_noise_gamma' 'J1614-2230_red_noise_log10_A'
#  'J1640+2224_dm_gp_gamma' 'J1640+2224_dm_gp_log10_A'
#  'J1640+2224_red_noise_gamma' 'J1640+2224_red_noise_log10_A'
#  'J1643-1224_dm_gp_gamma' 'J1643-1224_dm_gp_log10_A'
#  'J1643-1224_red_noise_gamma' 'J1643-1224_red_noise_log10_A'
#  'J1713+0747_dm_gp_gamma' 'J1713+0747_dm_gp_log10_A'
#  'J1713+0747_exp1_log10_Amp' 'J1713+0747_exp1_log10_tau'
#  'J1713+0747_exp1_t0' 'J1713+0747_red_noise_gamma'
#  'J1713+0747_red_noise_log10_A' 'J1721-2457_dm_gp_gamma'
#  'J1721-2457_dm_gp_log10_A' 'J1721-2457_red_noise_gamma'
#  'J1721-2457_red_noise_log10_A' 'J1730-2304_dm_gp_gamma'
#  'J1730-2304_dm_gp_log10_A' 'J1730-2304_red_noise_gamma'
#  'J1730-2304_red_noise_log10_A' 'J1732-5049_dm_gp_gamma'
#  'J1732-5049_dm_gp_log10_A' 'J1732-5049_red_noise_gamma'
#  'J1732-5049_red_noise_log10_A' 'J1738+0333_dm_gp_gamma'
#  'J1738+0333_dm_gp_log10_A' 'J1738+0333_red_noise_gamma'
#  'J1738+0333_red_noise_log10_A' 'J1741+1351_dm_gp_gamma'
#  'J1741+1351_dm_gp_log10_A' 'J1741+1351_red_noise_gamma'
#  'J1741+1351_red_noise_log10_A' 'J1744-1134_dm_gp_gamma'
#  'J1744-1134_dm_gp_log10_A' 'J1744-1134_red_noise_gamma'
#  'J1744-1134_red_noise_log10_A' 'J1751-2857_dm_gp_gamma'
#  'J1751-2857_dm_gp_log10_A' 'J1751-2857_red_noise_gamma'
#  'J1751-2857_red_noise_log10_A' 'J1801-1417_dm_gp_gamma'
#  'J1801-1417_dm_gp_log10_A' 'J1801-1417_red_noise_gamma'
#  'J1801-1417_red_noise_log10_A' 'J1802-2124_dm_gp_gamma'
#  'J1802-2124_dm_gp_log10_A' 'J1802-2124_red_noise_gamma'
#  'J1802-2124_red_noise_log10_A' 'J1804-2717_dm_gp_gamma'
#  'J1804-2717_dm_gp_log10_A' 'J1804-2717_red_noise_gamma'
#  'J1804-2717_red_noise_log10_A' 'J1824-2452A_dm_gp_gamma'
#  'J1824-2452A_dm_gp_log10_A' 'J1824-2452A_red_noise_gamma'
#  'J1824-2452A_red_noise_log10_A' 'J1843-1113_dm_gp_gamma'
#  'J1843-1113_dm_gp_log10_A' 'J1843-1113_red_noise_gamma'
#  'J1843-1113_red_noise_log10_A' 'J1853+1303_dm_gp_gamma'
#  'J1853+1303_dm_gp_log10_A' 'J1853+1303_red_noise_gamma'
#  'J1853+1303_red_noise_log10_A' 'J1857+0943_dm_gp_gamma'
#  'J1857+0943_dm_gp_log10_A' 'J1857+0943_red_noise_gamma'
#  'J1857+0943_red_noise_log10_A' 'J1903+0327_dm_gp_gamma'
#  'J1903+0327_dm_gp_log10_A' 'J1903+0327_red_noise_gamma'
#  'J1903+0327_red_noise_log10_A' 'J1909-3744_dm_gp_gamma'
#  'J1909-3744_dm_gp_log10_A' 'J1909-3744_red_noise_gamma'
#  'J1909-3744_red_noise_log10_A' 'J1910+1256_dm_gp_gamma'
#  'J1910+1256_dm_gp_log10_A' 'J1910+1256_red_noise_gamma'
#  'J1910+1256_red_noise_log10_A' 'J1911+1347_dm_gp_gamma'
#  'J1911+1347_dm_gp_log10_A' 'J1911+1347_red_noise_gamma'
#  'J1911+1347_red_noise_log10_A' 'J1911-1114_dm_gp_gamma'
#  'J1911-1114_dm_gp_log10_A' 'J1911-1114_red_noise_gamma'
#  'J1911-1114_red_noise_log10_A' 'J1918-0642_dm_gp_gamma'
#  'J1918-0642_dm_gp_log10_A' 'J1918-0642_red_noise_gamma'
#  'J1918-0642_red_noise_log10_A' 'J1939+2134_dm_gp_gamma'
#  'J1939+2134_dm_gp_log10_A' 'J1939+2134_red_noise_gamma'
#  'J1939+2134_red_noise_log10_A' 'J1944+0907_dm_gp_gamma'
#  'J1944+0907_dm_gp_log10_A' 'J1944+0907_red_noise_gamma'
#  'J1944+0907_red_noise_log10_A' 'J1955+2908_dm_gp_gamma'
#  'J1955+2908_dm_gp_log10_A' 'J1955+2908_red_noise_gamma'
#  'J1955+2908_red_noise_log10_A' 'J2010-1323_dm_gp_gamma'
#  'J2010-1323_dm_gp_log10_A' 'J2010-1323_red_noise_gamma'
#  'J2010-1323_red_noise_log10_A' 'J2019+2425_dm_gp_gamma'
#  'J2019+2425_dm_gp_log10_A' 'J2019+2425_red_noise_gamma'
#  'J2019+2425_red_noise_log10_A' 'J2033+1734_dm_gp_gamma'
#  'J2033+1734_dm_gp_log10_A' 'J2033+1734_red_noise_gamma'
#  'J2033+1734_red_noise_log10_A' 'J2124-3358_dm_gp_gamma'
#  'J2124-3358_dm_gp_log10_A' 'J2124-3358_red_noise_gamma'
#  'J2124-3358_red_noise_log10_A' 'J2129-5721_dm_gp_gamma'
#  'J2129-5721_dm_gp_log10_A' 'J2129-5721_red_noise_gamma'
#  'J2129-5721_red_noise_log10_A' 'J2145-0750_dm_gp_gamma'
#  'J2145-0750_dm_gp_log10_A' 'J2145-0750_red_noise_gamma'
#  'J2145-0750_red_noise_log10_A' 'J2229+2643_dm_gp_gamma'
#  'J2229+2643_dm_gp_log10_A' 'J2229+2643_red_noise_gamma'
#  'J2229+2643_red_noise_log10_A' 'J2317+1439_dm_gp_gamma'
#  'J2317+1439_dm_gp_log10_A' 'J2317+1439_red_noise_gamma'
#  'J2317+1439_red_noise_log10_A' 'J2322+2057_dm_gp_gamma'
#  'J2322+2057_dm_gp_log10_A' 'J2322+2057_red_noise_gamma'
#  'J2322+2057_red_noise_log10_A' 'crn_log10_A']
# ['J0030+0451_red_noise_gamma' 'J0030+0451_red_noise_log10_A']
# ['J0030+0451_red_noise_gamma' 'J0030+0451_red_noise_log10_A' 'crn_log10_A']
# ['J0030+0451_red_noise_gamma' 'J0030+0451_red_noise_log10_A']
# ['J0030+0451_red_noise_gamma' 'J0030+0451_red_noise_log10_A' 'crn_log10_A']
# ['J0034-0534_red_noise_gamma' 'J0034-0534_red_noise_log10_A']
# ['J0034-0534_red_noise_gamma' 'J0034-0534_red_noise_log10_A' 'crn_log10_A']
# ['J0034-0534_red_noise_gamma' 'J0034-0534_red_noise_log10_A']
# ['J0034-0534_red_noise_gamma' 'J0034-0534_red_noise_log10_A' 'crn_log10_A']
# ['J0218+4232_red_noise_gamma' 'J0218+4232_red_noise_log10_A']
# ['J0218+4232_red_noise_gamma' 'J0218+4232_red_noise_log10_A' 'crn_log10_A']
# ['J0218+4232_red_noise_gamma' 'J0218+4232_red_noise_log10_A']
# ['J0218+4232_red_noise_gamma' 'J0218+4232_red_noise_log10_A' 'crn_log10_A']
# ['J0437-4715_red_noise_gamma' 'J0437-4715_red_noise_log10_A']
# ['J0437-4715_red_noise_gamma' 'J0437-4715_red_noise_log10_A' 'crn_log10_A']
# ['J0437-4715_red_noise_gamma' 'J0437-4715_red_noise_log10_A']
# ['J0437-4715_red_noise_gamma' 'J0437-4715_red_noise_log10_A' 'crn_log10_A']
# ['J0610-2100_red_noise_gamma' 'J0610-2100_red_noise_log10_A']
# ['J0610-2100_red_noise_gamma' 'J0610-2100_red_noise_log10_A' 'crn_log10_A']
# ['J0610-2100_red_noise_gamma' 'J0610-2100_red_noise_log10_A']
# ['J0610-2100_red_noise_gamma' 'J0610-2100_red_noise_log10_A' 'crn_log10_A']
# ['J0613-0200_red_noise_gamma' 'J0613-0200_red_noise_log10_A']
# ['J0613-0200_red_noise_gamma' 'J0613-0200_red_noise_log10_A' 'crn_log10_A']
# ['J0613-0200_red_noise_gamma' 'J0613-0200_red_noise_log10_A']
# ['J0613-0200_red_noise_gamma' 'J0613-0200_red_noise_log10_A' 'crn_log10_A']
# ['J0621+1002_red_noise_gamma' 'J0621+1002_red_noise_log10_A']
# ['J0621+1002_red_noise_gamma' 'J0621+1002_red_noise_log10_A' 'crn_log10_A']
# ['J0621+1002_red_noise_gamma' 'J0621+1002_red_noise_log10_A']
# ['J0621+1002_red_noise_gamma' 'J0621+1002_red_noise_log10_A' 'crn_log10_A']
# ['J0711-6830_red_noise_gamma' 'J0711-6830_red_noise_log10_A']
# ['J0711-6830_red_noise_gamma' 'J0711-6830_red_noise_log10_A' 'crn_log10_A']
# ['J0711-6830_red_noise_gamma' 'J0711-6830_red_noise_log10_A']
# ['J0711-6830_red_noise_gamma' 'J0711-6830_red_noise_log10_A' 'crn_log10_A']
# ['J0751+1807_red_noise_gamma' 'J0751+1807_red_noise_log10_A']
# ['J0751+1807_red_noise_gamma' 'J0751+1807_red_noise_log10_A' 'crn_log10_A']
# ['J0751+1807_red_noise_gamma' 'J0751+1807_red_noise_log10_A']
# ['J0751+1807_red_noise_gamma' 'J0751+1807_red_noise_log10_A' 'crn_log10_A']
# ['J0900-3144_red_noise_gamma' 'J0900-3144_red_noise_log10_A']
# ['J0900-3144_red_noise_gamma' 'J0900-3144_red_noise_log10_A' 'crn_log10_A']
# ['J0900-3144_red_noise_gamma' 'J0900-3144_red_noise_log10_A']
# ['J0900-3144_red_noise_gamma' 'J0900-3144_red_noise_log10_A' 'crn_log10_A']
# ['J1012+5307_red_noise_gamma' 'J1012+5307_red_noise_log10_A']
# ['J1012+5307_red_noise_gamma' 'J1012+5307_red_noise_log10_A' 'crn_log10_A']
# ['J1012+5307_red_noise_gamma' 'J1012+5307_red_noise_log10_A']
# ['J1012+5307_red_noise_gamma' 'J1012+5307_red_noise_log10_A' 'crn_log10_A']
# ['J1022+1001_red_noise_gamma' 'J1022+1001_red_noise_log10_A']
# ['J1022+1001_red_noise_gamma' 'J1022+1001_red_noise_log10_A' 'crn_log10_A']
# ['J1022+1001_red_noise_gamma' 'J1022+1001_red_noise_log10_A']
# ['J1022+1001_red_noise_gamma' 'J1022+1001_red_noise_log10_A' 'crn_log10_A']
# ['J1024-0719_red_noise_gamma' 'J1024-0719_red_noise_log10_A']
# ['J1024-0719_red_noise_gamma' 'J1024-0719_red_noise_log10_A' 'crn_log10_A']
# ['J1024-0719_red_noise_gamma' 'J1024-0719_red_noise_log10_A']
# ['J1024-0719_red_noise_gamma' 'J1024-0719_red_noise_log10_A' 'crn_log10_A']
# ['J1045-4509_red_noise_gamma' 'J1045-4509_red_noise_log10_A']
# ['J1045-4509_red_noise_gamma' 'J1045-4509_red_noise_log10_A' 'crn_log10_A']
# ['J1045-4509_red_noise_gamma' 'J1045-4509_red_noise_log10_A']
# ['J1045-4509_red_noise_gamma' 'J1045-4509_red_noise_log10_A' 'crn_log10_A']
# ['J1455-3330_red_noise_gamma' 'J1455-3330_red_noise_log10_A']
# ['J1455-3330_red_noise_gamma' 'J1455-3330_red_noise_log10_A' 'crn_log10_A']
# ['J1455-3330_red_noise_gamma' 'J1455-3330_red_noise_log10_A']
# ['J1455-3330_red_noise_gamma' 'J1455-3330_red_noise_log10_A' 'crn_log10_A']
# ['J1600-3053_red_noise_gamma' 'J1600-3053_red_noise_log10_A']
# ['J1600-3053_red_noise_gamma' 'J1600-3053_red_noise_log10_A' 'crn_log10_A']
# ['J1600-3053_red_noise_gamma' 'J1600-3053_red_noise_log10_A']
# ['J1600-3053_red_noise_gamma' 'J1600-3053_red_noise_log10_A' 'crn_log10_A']
# ['J1603-7202_red_noise_gamma' 'J1603-7202_red_noise_log10_A']
# ['J1603-7202_red_noise_gamma' 'J1603-7202_red_noise_log10_A' 'crn_log10_A']
# ['J1603-7202_red_noise_gamma' 'J1603-7202_red_noise_log10_A']
# ['J1603-7202_red_noise_gamma' 'J1603-7202_red_noise_log10_A' 'crn_log10_A']
# ['J1614-2230_red_noise_gamma' 'J1614-2230_red_noise_log10_A']
# ['J1614-2230_red_noise_gamma' 'J1614-2230_red_noise_log10_A' 'crn_log10_A']
# ['J1614-2230_red_noise_gamma' 'J1614-2230_red_noise_log10_A']
# ['J1614-2230_red_noise_gamma' 'J1614-2230_red_noise_log10_A' 'crn_log10_A']
# ['J1640+2224_red_noise_gamma' 'J1640+2224_red_noise_log10_A']
# ['J1640+2224_red_noise_gamma' 'J1640+2224_red_noise_log10_A' 'crn_log10_A']
# ['J1640+2224_red_noise_gamma' 'J1640+2224_red_noise_log10_A']
# ['J1640+2224_red_noise_gamma' 'J1640+2224_red_noise_log10_A' 'crn_log10_A']
# ['J1643-1224_red_noise_gamma' 'J1643-1224_red_noise_log10_A']
# ['J1643-1224_red_noise_gamma' 'J1643-1224_red_noise_log10_A' 'crn_log10_A']
# ['J1643-1224_red_noise_gamma' 'J1643-1224_red_noise_log10_A']
# ['J1643-1224_red_noise_gamma' 'J1643-1224_red_noise_log10_A' 'crn_log10_A']
# ['J1713+0747_red_noise_gamma' 'J1713+0747_red_noise_log10_A']
# ['J1713+0747_red_noise_gamma' 'J1713+0747_red_noise_log10_A' 'crn_log10_A']
# ['J1713+0747_red_noise_gamma' 'J1713+0747_red_noise_log10_A']
# ['J1713+0747_red_noise_gamma' 'J1713+0747_red_noise_log10_A' 'crn_log10_A']
# ['J1713+0747_red_noise_gamma' 'J1713+0747_red_noise_log10_A']
# ['J1713+0747_red_noise_gamma' 'J1713+0747_red_noise_log10_A' 'crn_log10_A']
# ['J1721-2457_red_noise_gamma' 'J1721-2457_red_noise_log10_A']
# ['J1721-2457_red_noise_gamma' 'J1721-2457_red_noise_log10_A' 'crn_log10_A']
# ['J1721-2457_red_noise_gamma' 'J1721-2457_red_noise_log10_A']
# ['J1721-2457_red_noise_gamma' 'J1721-2457_red_noise_log10_A' 'crn_log10_A']
# ['J1730-2304_red_noise_gamma' 'J1730-2304_red_noise_log10_A']
# ['J1730-2304_red_noise_gamma' 'J1730-2304_red_noise_log10_A' 'crn_log10_A']
# ['J1730-2304_red_noise_gamma' 'J1730-2304_red_noise_log10_A']
# ['J1730-2304_red_noise_gamma' 'J1730-2304_red_noise_log10_A' 'crn_log10_A']
# ['J1732-5049_red_noise_gamma' 'J1732-5049_red_noise_log10_A']
# ['J1732-5049_red_noise_gamma' 'J1732-5049_red_noise_log10_A' 'crn_log10_A']
# ['J1732-5049_red_noise_gamma' 'J1732-5049_red_noise_log10_A']
# ['J1732-5049_red_noise_gamma' 'J1732-5049_red_noise_log10_A' 'crn_log10_A']
# ['J1738+0333_red_noise_gamma' 'J1738+0333_red_noise_log10_A']
# ['J1738+0333_red_noise_gamma' 'J1738+0333_red_noise_log10_A' 'crn_log10_A']
# ['J1738+0333_red_noise_gamma' 'J1738+0333_red_noise_log10_A']
# ['J1738+0333_red_noise_gamma' 'J1738+0333_red_noise_log10_A' 'crn_log10_A']
# ['J1741+1351_red_noise_gamma' 'J1741+1351_red_noise_log10_A']
# ['J1741+1351_red_noise_gamma' 'J1741+1351_red_noise_log10_A' 'crn_log10_A']
# ['J1741+1351_red_noise_gamma' 'J1741+1351_red_noise_log10_A']
# ['J1741+1351_red_noise_gamma' 'J1741+1351_red_noise_log10_A' 'crn_log10_A']
# ['J1744-1134_red_noise_gamma' 'J1744-1134_red_noise_log10_A']
# ['J1744-1134_red_noise_gamma' 'J1744-1134_red_noise_log10_A' 'crn_log10_A']
# ['J1744-1134_red_noise_gamma' 'J1744-1134_red_noise_log10_A']
# ['J1744-1134_red_noise_gamma' 'J1744-1134_red_noise_log10_A' 'crn_log10_A']
# ['J1751-2857_red_noise_gamma' 'J1751-2857_red_noise_log10_A']
# ['J1751-2857_red_noise_gamma' 'J1751-2857_red_noise_log10_A' 'crn_log10_A']
# ['J1751-2857_red_noise_gamma' 'J1751-2857_red_noise_log10_A']
# ['J1751-2857_red_noise_gamma' 'J1751-2857_red_noise_log10_A' 'crn_log10_A']
# ['J1801-1417_red_noise_gamma' 'J1801-1417_red_noise_log10_A']
# ['J1801-1417_red_noise_gamma' 'J1801-1417_red_noise_log10_A' 'crn_log10_A']
# ['J1801-1417_red_noise_gamma' 'J1801-1417_red_noise_log10_A']
# ['J1801-1417_red_noise_gamma' 'J1801-1417_red_noise_log10_A' 'crn_log10_A']
# ['J1802-2124_red_noise_gamma' 'J1802-2124_red_noise_log10_A']
# ['J1802-2124_red_noise_gamma' 'J1802-2124_red_noise_log10_A' 'crn_log10_A']
# ['J1802-2124_red_noise_gamma' 'J1802-2124_red_noise_log10_A']
# ['J1802-2124_red_noise_gamma' 'J1802-2124_red_noise_log10_A' 'crn_log10_A']
# ['J1804-2717_red_noise_gamma' 'J1804-2717_red_noise_log10_A']
# ['J1804-2717_red_noise_gamma' 'J1804-2717_red_noise_log10_A' 'crn_log10_A']
# ['J1804-2717_red_noise_gamma' 'J1804-2717_red_noise_log10_A']
# ['J1804-2717_red_noise_gamma' 'J1804-2717_red_noise_log10_A' 'crn_log10_A']
# ['J1824-2452A_red_noise_gamma' 'J1824-2452A_red_noise_log10_A']
# ['J1824-2452A_red_noise_gamma' 'J1824-2452A_red_noise_log10_A'
#  'crn_log10_A']
# ['J1824-2452A_red_noise_gamma' 'J1824-2452A_red_noise_log10_A']
# ['J1824-2452A_red_noise_gamma' 'J1824-2452A_red_noise_log10_A'
#  'crn_log10_A']
# ['J1843-1113_red_noise_gamma' 'J1843-1113_red_noise_log10_A']
# ['J1843-1113_red_noise_gamma' 'J1843-1113_red_noise_log10_A' 'crn_log10_A']
# ['J1843-1113_red_noise_gamma' 'J1843-1113_red_noise_log10_A']
# ['J1843-1113_red_noise_gamma' 'J1843-1113_red_noise_log10_A' 'crn_log10_A']
# ['J1853+1303_red_noise_gamma' 'J1853+1303_red_noise_log10_A']
# ['J1853+1303_red_noise_gamma' 'J1853+1303_red_noise_log10_A' 'crn_log10_A']
# ['J1853+1303_red_noise_gamma' 'J1853+1303_red_noise_log10_A']
# ['J1853+1303_red_noise_gamma' 'J1853+1303_red_noise_log10_A' 'crn_log10_A']
# ['J1857+0943_red_noise_gamma' 'J1857+0943_red_noise_log10_A']
# ['J1857+0943_red_noise_gamma' 'J1857+0943_red_noise_log10_A' 'crn_log10_A']
# ['J1857+0943_red_noise_gamma' 'J1857+0943_red_noise_log10_A']
# ['J1857+0943_red_noise_gamma' 'J1857+0943_red_noise_log10_A' 'crn_log10_A']
# ['J1903+0327_red_noise_gamma' 'J1903+0327_red_noise_log10_A']
# ['J1903+0327_red_noise_gamma' 'J1903+0327_red_noise_log10_A' 'crn_log10_A']
# ['J1903+0327_red_noise_gamma' 'J1903+0327_red_noise_log10_A']
# ['J1903+0327_red_noise_gamma' 'J1903+0327_red_noise_log10_A' 'crn_log10_A']
# ['J1909-3744_red_noise_gamma' 'J1909-3744_red_noise_log10_A']
# ['J1909-3744_red_noise_gamma' 'J1909-3744_red_noise_log10_A' 'crn_log10_A']
# ['J1909-3744_red_noise_gamma' 'J1909-3744_red_noise_log10_A']
# ['J1909-3744_red_noise_gamma' 'J1909-3744_red_noise_log10_A' 'crn_log10_A']
# ['J1910+1256_red_noise_gamma' 'J1910+1256_red_noise_log10_A']
# ['J1910+1256_red_noise_gamma' 'J1910+1256_red_noise_log10_A' 'crn_log10_A']
# ['J1910+1256_red_noise_gamma' 'J1910+1256_red_noise_log10_A']
# ['J1910+1256_red_noise_gamma' 'J1910+1256_red_noise_log10_A' 'crn_log10_A']
# ['J1911+1347_red_noise_gamma' 'J1911+1347_red_noise_log10_A']
# ['J1911+1347_red_noise_gamma' 'J1911+1347_red_noise_log10_A' 'crn_log10_A']
# ['J1911+1347_red_noise_gamma' 'J1911+1347_red_noise_log10_A']
# ['J1911+1347_red_noise_gamma' 'J1911+1347_red_noise_log10_A' 'crn_log10_A']
# ['J1911-1114_red_noise_gamma' 'J1911-1114_red_noise_log10_A']
# ['J1911-1114_red_noise_gamma' 'J1911-1114_red_noise_log10_A' 'crn_log10_A']
# ['J1911-1114_red_noise_gamma' 'J1911-1114_red_noise_log10_A']
# ['J1911-1114_red_noise_gamma' 'J1911-1114_red_noise_log10_A' 'crn_log10_A']
# ['J1918-0642_red_noise_gamma' 'J1918-0642_red_noise_log10_A']
# ['J1918-0642_red_noise_gamma' 'J1918-0642_red_noise_log10_A' 'crn_log10_A']
# ['J1918-0642_red_noise_gamma' 'J1918-0642_red_noise_log10_A']
# ['J1918-0642_red_noise_gamma' 'J1918-0642_red_noise_log10_A' 'crn_log10_A']
# ['J1939+2134_red_noise_gamma' 'J1939+2134_red_noise_log10_A']
# ['J1939+2134_red_noise_gamma' 'J1939+2134_red_noise_log10_A' 'crn_log10_A']
# ['J1939+2134_red_noise_gamma' 'J1939+2134_red_noise_log10_A']
# ['J1939+2134_red_noise_gamma' 'J1939+2134_red_noise_log10_A' 'crn_log10_A']
# ['J1944+0907_red_noise_gamma' 'J1944+0907_red_noise_log10_A']
# ['J1944+0907_red_noise_gamma' 'J1944+0907_red_noise_log10_A' 'crn_log10_A']
# ['J1944+0907_red_noise_gamma' 'J1944+0907_red_noise_log10_A']
# ['J1944+0907_red_noise_gamma' 'J1944+0907_red_noise_log10_A' 'crn_log10_A']
# ['J1955+2908_red_noise_gamma' 'J1955+2908_red_noise_log10_A']
# ['J1955+2908_red_noise_gamma' 'J1955+2908_red_noise_log10_A' 'crn_log10_A']
# ['J1955+2908_red_noise_gamma' 'J1955+2908_red_noise_log10_A']
# ['J1955+2908_red_noise_gamma' 'J1955+2908_red_noise_log10_A' 'crn_log10_A']
# ['J2010-1323_red_noise_gamma' 'J2010-1323_red_noise_log10_A']
# ['J2010-1323_red_noise_gamma' 'J2010-1323_red_noise_log10_A' 'crn_log10_A']
# ['J2010-1323_red_noise_gamma' 'J2010-1323_red_noise_log10_A']
# ['J2010-1323_red_noise_gamma' 'J2010-1323_red_noise_log10_A' 'crn_log10_A']
# ['J2019+2425_red_noise_gamma' 'J2019+2425_red_noise_log10_A']
# ['J2019+2425_red_noise_gamma' 'J2019+2425_red_noise_log10_A' 'crn_log10_A']
# ['J2019+2425_red_noise_gamma' 'J2019+2425_red_noise_log10_A']
# ['J2019+2425_red_noise_gamma' 'J2019+2425_red_noise_log10_A' 'crn_log10_A']
# ['J2033+1734_red_noise_gamma' 'J2033+1734_red_noise_log10_A']
# ['J2033+1734_red_noise_gamma' 'J2033+1734_red_noise_log10_A' 'crn_log10_A']
# ['J2033+1734_red_noise_gamma' 'J2033+1734_red_noise_log10_A']
# ['J2033+1734_red_noise_gamma' 'J2033+1734_red_noise_log10_A' 'crn_log10_A']
# ['J2124-3358_red_noise_gamma' 'J2124-3358_red_noise_log10_A']
# ['J2124-3358_red_noise_gamma' 'J2124-3358_red_noise_log10_A' 'crn_log10_A']
# ['J2124-3358_red_noise_gamma' 'J2124-3358_red_noise_log10_A']
# ['J2124-3358_red_noise_gamma' 'J2124-3358_red_noise_log10_A' 'crn_log10_A']
# ['J2129-5721_red_noise_gamma' 'J2129-5721_red_noise_log10_A']
# ['J2129-5721_red_noise_gamma' 'J2129-5721_red_noise_log10_A' 'crn_log10_A']
# ['J2129-5721_red_noise_gamma' 'J2129-5721_red_noise_log10_A']
# ['J2129-5721_red_noise_gamma' 'J2129-5721_red_noise_log10_A' 'crn_log10_A']
# ['J2145-0750_red_noise_gamma' 'J2145-0750_red_noise_log10_A']
# ['J2145-0750_red_noise_gamma' 'J2145-0750_red_noise_log10_A' 'crn_log10_A']
# ['J2145-0750_red_noise_gamma' 'J2145-0750_red_noise_log10_A']
# ['J2145-0750_red_noise_gamma' 'J2145-0750_red_noise_log10_A' 'crn_log10_A']
# ['J2229+2643_red_noise_gamma' 'J2229+2643_red_noise_log10_A']
# ['J2229+2643_red_noise_gamma' 'J2229+2643_red_noise_log10_A' 'crn_log10_A']
# ['J2229+2643_red_noise_gamma' 'J2229+2643_red_noise_log10_A']
# ['J2229+2643_red_noise_gamma' 'J2229+2643_red_noise_log10_A' 'crn_log10_A']
# ['J2317+1439_red_noise_gamma' 'J2317+1439_red_noise_log10_A']
# ['J2317+1439_red_noise_gamma' 'J2317+1439_red_noise_log10_A' 'crn_log10_A']
# ['J2317+1439_red_noise_gamma' 'J2317+1439_red_noise_log10_A']
# ['J2317+1439_red_noise_gamma' 'J2317+1439_red_noise_log10_A' 'crn_log10_A']
# ['J2322+2057_red_noise_gamma' 'J2322+2057_red_noise_log10_A']
# ['J2322+2057_red_noise_gamma' 'J2322+2057_red_noise_log10_A' 'crn_log10_A']
# ['J2322+2057_red_noise_gamma' 'J2322+2057_red_noise_log10_A']
# ['J2322+2057_red_noise_gamma' 'J2322+2057_red_noise_log10_A' 'crn_log10_A']
# ['J0030+0451_red_noise_gamma' 'J0030+0451_red_noise_log10_A'
#  'J0034-0534_red_noise_gamma' 'J0034-0534_red_noise_log10_A'
#  'J0218+4232_red_noise_gamma' 'J0218+4232_red_noise_log10_A'
#  'J0437-4715_red_noise_gamma' 'J0437-4715_red_noise_log10_A'
#  'J0610-2100_red_noise_gamma' 'J0610-2100_red_noise_log10_A'
#  'J0613-0200_red_noise_gamma' 'J0613-0200_red_noise_log10_A'
#  'J0621+1002_red_noise_gamma' 'J0621+1002_red_noise_log10_A'
#  'J0711-6830_red_noise_gamma' 'J0711-6830_red_noise_log10_A'
#  'J0751+1807_red_noise_gamma' 'J0751+1807_red_noise_log10_A'
#  'J0900-3144_red_noise_gamma' 'J0900-3144_red_noise_log10_A'
#  'J1012+5307_red_noise_gamma' 'J1012+5307_red_noise_log10_A'
#  'J1022+1001_red_noise_gamma' 'J1022+1001_red_noise_log10_A'
#  'J1024-0719_red_noise_gamma' 'J1024-0719_red_noise_log10_A'
#  'J1045-4509_red_noise_gamma' 'J1045-4509_red_noise_log10_A'
#  'J1455-3330_red_noise_gamma' 'J1455-3330_red_noise_log10_A'
#  'J1600-3053_red_noise_gamma' 'J1600-3053_red_noise_log10_A'
#  'J1603-7202_red_noise_gamma' 'J1603-7202_red_noise_log10_A'
#  'J1614-2230_red_noise_gamma' 'J1614-2230_red_noise_log10_A'
#  'J1640+2224_red_noise_gamma' 'J1640+2224_red_noise_log10_A'
#  'J1643-1224_red_noise_gamma' 'J1643-1224_red_noise_log10_A'
#  'J1713+0747_red_noise_gamma' 'J1713+0747_red_noise_log10_A'
#  'J1721-2457_red_noise_gamma' 'J1721-2457_red_noise_log10_A'
#  'J1730-2304_red_noise_gamma' 'J1730-2304_red_noise_log10_A'
#  'J1732-5049_red_noise_gamma' 'J1732-5049_red_noise_log10_A'
#  'J1738+0333_red_noise_gamma' 'J1738+0333_red_noise_log10_A'
#  'J1741+1351_red_noise_gamma' 'J1741+1351_red_noise_log10_A'
#  'J1744-1134_red_noise_gamma' 'J1744-1134_red_noise_log10_A'
#  'J1751-2857_red_noise_gamma' 'J1751-2857_red_noise_log10_A'
#  'J1801-1417_red_noise_gamma' 'J1801-1417_red_noise_log10_A'
#  'J1802-2124_red_noise_gamma' 'J1802-2124_red_noise_log10_A'
#  'J1804-2717_red_noise_gamma' 'J1804-2717_red_noise_log10_A'
#  'J1824-2452A_red_noise_gamma' 'J1824-2452A_red_noise_log10_A'
#  'J1843-1113_red_noise_gamma' 'J1843-1113_red_noise_log10_A'
#  'J1853+1303_red_noise_gamma' 'J1853+1303_red_noise_log10_A'
#  'J1857+0943_red_noise_gamma' 'J1857+0943_red_noise_log10_A'
#  'J1903+0327_red_noise_gamma' 'J1903+0327_red_noise_log10_A'
#  'J1909-3744_red_noise_gamma' 'J1909-3744_red_noise_log10_A'
#  'J1910+1256_red_noise_gamma' 'J1910+1256_red_noise_log10_A'
#  'J1911+1347_red_noise_gamma' 'J1911+1347_red_noise_log10_A'
#  'J1911-1114_red_noise_gamma' 'J1911-1114_red_noise_log10_A'
#  'J1918-0642_red_noise_gamma' 'J1918-0642_red_noise_log10_A'
#  'J1939+2134_red_noise_gamma' 'J1939+2134_red_noise_log10_A'
#  'J1944+0907_red_noise_gamma' 'J1944+0907_red_noise_log10_A'
#  'J1955+2908_red_noise_gamma' 'J1955+2908_red_noise_log10_A'
#  'J2010-1323_red_noise_gamma' 'J2010-1323_red_noise_log10_A'
#  'J2019+2425_red_noise_gamma' 'J2019+2425_red_noise_log10_A'
#  'J2033+1734_red_noise_gamma' 'J2033+1734_red_noise_log10_A'
#  'J2124-3358_red_noise_gamma' 'J2124-3358_red_noise_log10_A'
#  'J2129-5721_red_noise_gamma' 'J2129-5721_red_noise_log10_A'
#  'J2145-0750_red_noise_gamma' 'J2145-0750_red_noise_log10_A'
#  'J2229+2643_red_noise_gamma' 'J2229+2643_red_noise_log10_A'
#  'J2317+1439_red_noise_gamma' 'J2317+1439_red_noise_log10_A'
#  'J2322+2057_red_noise_gamma' 'J2322+2057_red_noise_log10_A' 'crn_log10_A']
# ['J0030+0451_red_noise_gamma' 'J0030+0451_red_noise_log10_A'
#  'J0034-0534_red_noise_gamma' 'J0034-0534_red_noise_log10_A'
#  'J0218+4232_red_noise_gamma' 'J0218+4232_red_noise_log10_A'
#  'J0437-4715_red_noise_gamma' 'J0437-4715_red_noise_log10_A'
#  'J0610-2100_red_noise_gamma' 'J0610-2100_red_noise_log10_A'
#  'J0613-0200_red_noise_gamma' 'J0613-0200_red_noise_log10_A'
#  'J0621+1002_red_noise_gamma' 'J0621+1002_red_noise_log10_A'
#  'J0711-6830_red_noise_gamma' 'J0711-6830_red_noise_log10_A'
#  'J0751+1807_red_noise_gamma' 'J0751+1807_red_noise_log10_A'
#  'J0900-3144_red_noise_gamma' 'J0900-3144_red_noise_log10_A'
#  'J1012+5307_red_noise_gamma' 'J1012+5307_red_noise_log10_A'
#  'J1022+1001_red_noise_gamma' 'J1022+1001_red_noise_log10_A'
#  'J1024-0719_red_noise_gamma' 'J1024-0719_red_noise_log10_A'
#  'J1045-4509_red_noise_gamma' 'J1045-4509_red_noise_log10_A'
#  'J1455-3330_red_noise_gamma' 'J1455-3330_red_noise_log10_A'
#  'J1600-3053_red_noise_gamma' 'J1600-3053_red_noise_log10_A'
#  'J1603-7202_red_noise_gamma' 'J1603-7202_red_noise_log10_A'
#  'J1614-2230_red_noise_gamma' 'J1614-2230_red_noise_log10_A'
#  'J1640+2224_red_noise_gamma' 'J1640+2224_red_noise_log10_A'
#  'J1643-1224_red_noise_gamma' 'J1643-1224_red_noise_log10_A'
#  'J1713+0747_red_noise_gamma' 'J1713+0747_red_noise_log10_A'
#  'J1721-2457_red_noise_gamma' 'J1721-2457_red_noise_log10_A'
#  'J1730-2304_red_noise_gamma' 'J1730-2304_red_noise_log10_A'
#  'J1732-5049_red_noise_gamma' 'J1732-5049_red_noise_log10_A'
#  'J1738+0333_red_noise_gamma' 'J1738+0333_red_noise_log10_A'
#  'J1741+1351_red_noise_gamma' 'J1741+1351_red_noise_log10_A'
#  'J1744-1134_red_noise_gamma' 'J1744-1134_red_noise_log10_A'
#  'J1751-2857_red_noise_gamma' 'J1751-2857_red_noise_log10_A'
#  'J1801-1417_red_noise_gamma' 'J1801-1417_red_noise_log10_A'
#  'J1802-2124_red_noise_gamma' 'J1802-2124_red_noise_log10_A'
#  'J1804-2717_red_noise_gamma' 'J1804-2717_red_noise_log10_A'
#  'J1824-2452A_red_noise_gamma' 'J1824-2452A_red_noise_log10_A'
#  'J1843-1113_red_noise_gamma' 'J1843-1113_red_noise_log10_A'
#  'J1853+1303_red_noise_gamma' 'J1853+1303_red_noise_log10_A'
#  'J1857+0943_red_noise_gamma' 'J1857+0943_red_noise_log10_A'
#  'J1903+0327_red_noise_gamma' 'J1903+0327_red_noise_log10_A'
#  'J1909-3744_red_noise_gamma' 'J1909-3744_red_noise_log10_A'
#  'J1910+1256_red_noise_gamma' 'J1910+1256_red_noise_log10_A'
#  'J1911+1347_red_noise_gamma' 'J1911+1347_red_noise_log10_A'
#  'J1911-1114_red_noise_gamma' 'J1911-1114_red_noise_log10_A'
#  'J1918-0642_red_noise_gamma' 'J1918-0642_red_noise_log10_A'
#  'J1939+2134_red_noise_gamma' 'J1939+2134_red_noise_log10_A'
#  'J1944+0907_red_noise_gamma' 'J1944+0907_red_noise_log10_A'
#  'J1955+2908_red_noise_gamma' 'J1955+2908_red_noise_log10_A'
#  'J2010-1323_red_noise_gamma' 'J2010-1323_red_noise_log10_A'
#  'J2019+2425_red_noise_gamma' 'J2019+2425_red_noise_log10_A'
#  'J2033+1734_red_noise_gamma' 'J2033+1734_red_noise_log10_A'
#  'J2124-3358_red_noise_gamma' 'J2124-3358_red_noise_log10_A'
#  'J2129-5721_red_noise_gamma' 'J2129-5721_red_noise_log10_A'
#  'J2145-0750_red_noise_gamma' 'J2145-0750_red_noise_log10_A'
#  'J2229+2643_red_noise_gamma' 'J2229+2643_red_noise_log10_A'
#  'J2317+1439_red_noise_gamma' 'J2317+1439_red_noise_log10_A'
#  'J2322+2057_red_noise_gamma' 'J2322+2057_red_noise_log10_A' 'crn_log10_A'
#  'crn_log10_A']
# ['crn_log10_A']
# ['crn_log10_A']
# ['J0030+0451_dm_gp_log10_A' 'J0030+0451_dm_gp_gamma']
# ['J0030+0451_dm_gp_log10_A' 'J0030+0451_dm_gp_gamma'
#  'J0030+0451_red_noise_log10_A' 'J0030+0451_red_noise_gamma']
# ['J0034-0534_dm_gp_log10_A' 'J0034-0534_dm_gp_gamma']
# ['J0034-0534_dm_gp_log10_A' 'J0034-0534_dm_gp_gamma'
#  'J0034-0534_red_noise_log10_A' 'J0034-0534_red_noise_gamma']
# ['J0218+4232_dm_gp_log10_A' 'J0218+4232_dm_gp_gamma']
# ['J0218+4232_dm_gp_log10_A' 'J0218+4232_dm_gp_gamma'
#  'J0218+4232_red_noise_log10_A' 'J0218+4232_red_noise_gamma']
# ['J0437-4715_dm_gp_log10_A' 'J0437-4715_dm_gp_gamma']
# ['J0437-4715_dm_gp_log10_A' 'J0437-4715_dm_gp_gamma'
#  'J0437-4715_red_noise_log10_A' 'J0437-4715_red_noise_gamma']
# ['J0610-2100_dm_gp_log10_A' 'J0610-2100_dm_gp_gamma']
# ['J0610-2100_dm_gp_log10_A' 'J0610-2100_dm_gp_gamma'
#  'J0610-2100_red_noise_log10_A' 'J0610-2100_red_noise_gamma']
# ['J0613-0200_dm_gp_log10_A' 'J0613-0200_dm_gp_gamma']
# ['J0613-0200_dm_gp_log10_A' 'J0613-0200_dm_gp_gamma'
#  'J0613-0200_red_noise_log10_A' 'J0613-0200_red_noise_gamma']
# ['J0621+1002_dm_gp_log10_A' 'J0621+1002_dm_gp_gamma']
# ['J0621+1002_dm_gp_log10_A' 'J0621+1002_dm_gp_gamma'
#  'J0621+1002_red_noise_log10_A' 'J0621+1002_red_noise_gamma']
# ['J0711-6830_dm_gp_log10_A' 'J0711-6830_dm_gp_gamma']
# ['J0711-6830_dm_gp_log10_A' 'J0711-6830_dm_gp_gamma'
#  'J0711-6830_red_noise_log10_A' 'J0711-6830_red_noise_gamma']
# ['J0751+1807_dm_gp_log10_A' 'J0751+1807_dm_gp_gamma']
# ['J0751+1807_dm_gp_log10_A' 'J0751+1807_dm_gp_gamma'
#  'J0751+1807_red_noise_log10_A' 'J0751+1807_red_noise_gamma']
# ['J0900-3144_dm_gp_log10_A' 'J0900-3144_dm_gp_gamma']
# ['J0900-3144_dm_gp_log10_A' 'J0900-3144_dm_gp_gamma'
#  'J0900-3144_red_noise_log10_A' 'J0900-3144_red_noise_gamma']
# ['J1012+5307_dm_gp_log10_A' 'J1012+5307_dm_gp_gamma']
# ['J1012+5307_dm_gp_log10_A' 'J1012+5307_dm_gp_gamma'
#  'J1012+5307_red_noise_log10_A' 'J1012+5307_red_noise_gamma']
# ['J1022+1001_dm_gp_log10_A' 'J1022+1001_dm_gp_gamma']
# ['J1022+1001_dm_gp_log10_A' 'J1022+1001_dm_gp_gamma'
#  'J1022+1001_red_noise_log10_A' 'J1022+1001_red_noise_gamma']
# ['J1024-0719_dm_gp_log10_A' 'J1024-0719_dm_gp_gamma']
# ['J1024-0719_dm_gp_log10_A' 'J1024-0719_dm_gp_gamma'
#  'J1024-0719_red_noise_log10_A' 'J1024-0719_red_noise_gamma']
# ['J1045-4509_dm_gp_log10_A' 'J1045-4509_dm_gp_gamma']
# ['J1045-4509_dm_gp_log10_A' 'J1045-4509_dm_gp_gamma'
#  'J1045-4509_red_noise_log10_A' 'J1045-4509_red_noise_gamma']
# ['J1455-3330_dm_gp_log10_A' 'J1455-3330_dm_gp_gamma']
# ['J1455-3330_dm_gp_log10_A' 'J1455-3330_dm_gp_gamma'
#  'J1455-3330_red_noise_log10_A' 'J1455-3330_red_noise_gamma']
# ['J1600-3053_dm_gp_log10_A' 'J1600-3053_dm_gp_gamma']
# ['J1600-3053_dm_gp_log10_A' 'J1600-3053_dm_gp_gamma'
#  'J1600-3053_red_noise_log10_A' 'J1600-3053_red_noise_gamma']
# ['J1603-7202_dm_gp_log10_A' 'J1603-7202_dm_gp_gamma']
# ['J1603-7202_dm_gp_log10_A' 'J1603-7202_dm_gp_gamma'
#  'J1603-7202_red_noise_log10_A' 'J1603-7202_red_noise_gamma']
# ['J1614-2230_dm_gp_log10_A' 'J1614-2230_dm_gp_gamma']
# ['J1614-2230_dm_gp_log10_A' 'J1614-2230_dm_gp_gamma'
#  'J1614-2230_red_noise_log10_A' 'J1614-2230_red_noise_gamma']
# ['J1640+2224_dm_gp_log10_A' 'J1640+2224_dm_gp_gamma']
# ['J1640+2224_dm_gp_log10_A' 'J1640+2224_dm_gp_gamma'
#  'J1640+2224_red_noise_log10_A' 'J1640+2224_red_noise_gamma']
# ['J1643-1224_dm_gp_log10_A' 'J1643-1224_dm_gp_gamma']
# ['J1643-1224_dm_gp_log10_A' 'J1643-1224_dm_gp_gamma'
#  'J1643-1224_red_noise_log10_A' 'J1643-1224_red_noise_gamma']
# ['J1713+0747_dm_gp_log10_A' 'J1713+0747_dm_gp_gamma']
# ['J1713+0747_dm_gp_log10_A' 'J1713+0747_dm_gp_gamma'
#  'J1713+0747_red_noise_log10_A' 'J1713+0747_red_noise_gamma']
# ['J1721-2457_dm_gp_log10_A' 'J1721-2457_dm_gp_gamma']
# ['J1721-2457_dm_gp_log10_A' 'J1721-2457_dm_gp_gamma'
#  'J1721-2457_red_noise_log10_A' 'J1721-2457_red_noise_gamma']
# ['J1730-2304_dm_gp_log10_A' 'J1730-2304_dm_gp_gamma']
# ['J1730-2304_dm_gp_log10_A' 'J1730-2304_dm_gp_gamma'
#  'J1730-2304_red_noise_log10_A' 'J1730-2304_red_noise_gamma']
# ['J1732-5049_dm_gp_log10_A' 'J1732-5049_dm_gp_gamma']
# ['J1732-5049_dm_gp_log10_A' 'J1732-5049_dm_gp_gamma'
#  'J1732-5049_red_noise_log10_A' 'J1732-5049_red_noise_gamma']
# ['J1738+0333_dm_gp_log10_A' 'J1738+0333_dm_gp_gamma']
# ['J1738+0333_dm_gp_log10_A' 'J1738+0333_dm_gp_gamma'
#  'J1738+0333_red_noise_log10_A' 'J1738+0333_red_noise_gamma']
# ['J1741+1351_dm_gp_log10_A' 'J1741+1351_dm_gp_gamma']
# ['J1741+1351_dm_gp_log10_A' 'J1741+1351_dm_gp_gamma'
#  'J1741+1351_red_noise_log10_A' 'J1741+1351_red_noise_gamma']
# ['J1744-1134_dm_gp_log10_A' 'J1744-1134_dm_gp_gamma']
# ['J1744-1134_dm_gp_log10_A' 'J1744-1134_dm_gp_gamma'
#  'J1744-1134_red_noise_log10_A' 'J1744-1134_red_noise_gamma']
# ['J1751-2857_dm_gp_log10_A' 'J1751-2857_dm_gp_gamma']
# ['J1751-2857_dm_gp_log10_A' 'J1751-2857_dm_gp_gamma'
#  'J1751-2857_red_noise_log10_A' 'J1751-2857_red_noise_gamma']
# ['J1801-1417_dm_gp_log10_A' 'J1801-1417_dm_gp_gamma']
# ['J1801-1417_dm_gp_log10_A' 'J1801-1417_dm_gp_gamma'
#  'J1801-1417_red_noise_log10_A' 'J1801-1417_red_noise_gamma']
# ['J1802-2124_dm_gp_log10_A' 'J1802-2124_dm_gp_gamma']
# ['J1802-2124_dm_gp_log10_A' 'J1802-2124_dm_gp_gamma'
#  'J1802-2124_red_noise_log10_A' 'J1802-2124_red_noise_gamma']
# ['J1804-2717_dm_gp_log10_A' 'J1804-2717_dm_gp_gamma']
# ['J1804-2717_dm_gp_log10_A' 'J1804-2717_dm_gp_gamma'
#  'J1804-2717_red_noise_log10_A' 'J1804-2717_red_noise_gamma']
# ['J1824-2452A_dm_gp_log10_A' 'J1824-2452A_dm_gp_gamma']
# ['J1824-2452A_dm_gp_log10_A' 'J1824-2452A_dm_gp_gamma'
#  'J1824-2452A_red_noise_log10_A' 'J1824-2452A_red_noise_gamma']
# ['J1843-1113_dm_gp_log10_A' 'J1843-1113_dm_gp_gamma']
# ['J1843-1113_dm_gp_log10_A' 'J1843-1113_dm_gp_gamma'
#  'J1843-1113_red_noise_log10_A' 'J1843-1113_red_noise_gamma']
# ['J1853+1303_dm_gp_log10_A' 'J1853+1303_dm_gp_gamma']
# ['J1853+1303_dm_gp_log10_A' 'J1853+1303_dm_gp_gamma'
#  'J1853+1303_red_noise_log10_A' 'J1853+1303_red_noise_gamma']
# ['J1857+0943_dm_gp_log10_A' 'J1857+0943_dm_gp_gamma']
# ['J1857+0943_dm_gp_log10_A' 'J1857+0943_dm_gp_gamma'
#  'J1857+0943_red_noise_log10_A' 'J1857+0943_red_noise_gamma']
# ['J1903+0327_dm_gp_log10_A' 'J1903+0327_dm_gp_gamma']
# ['J1903+0327_dm_gp_log10_A' 'J1903+0327_dm_gp_gamma'
#  'J1903+0327_red_noise_log10_A' 'J1903+0327_red_noise_gamma']
# ['J1909-3744_dm_gp_log10_A' 'J1909-3744_dm_gp_gamma']
# ['J1909-3744_dm_gp_log10_A' 'J1909-3744_dm_gp_gamma'
#  'J1909-3744_red_noise_log10_A' 'J1909-3744_red_noise_gamma']
# ['J1910+1256_dm_gp_log10_A' 'J1910+1256_dm_gp_gamma']
# ['J1910+1256_dm_gp_log10_A' 'J1910+1256_dm_gp_gamma'
#  'J1910+1256_red_noise_log10_A' 'J1910+1256_red_noise_gamma']
# ['J1911+1347_dm_gp_log10_A' 'J1911+1347_dm_gp_gamma']
# ['J1911+1347_dm_gp_log10_A' 'J1911+1347_dm_gp_gamma'
#  'J1911+1347_red_noise_log10_A' 'J1911+1347_red_noise_gamma']
# ['J1911-1114_dm_gp_log10_A' 'J1911-1114_dm_gp_gamma']
# ['J1911-1114_dm_gp_log10_A' 'J1911-1114_dm_gp_gamma'
#  'J1911-1114_red_noise_log10_A' 'J1911-1114_red_noise_gamma']
# ['J1918-0642_dm_gp_log10_A' 'J1918-0642_dm_gp_gamma']
# ['J1918-0642_dm_gp_log10_A' 'J1918-0642_dm_gp_gamma'
#  'J1918-0642_red_noise_log10_A' 'J1918-0642_red_noise_gamma']
# ['J1939+2134_dm_gp_log10_A' 'J1939+2134_dm_gp_gamma']
# ['J1939+2134_dm_gp_log10_A' 'J1939+2134_dm_gp_gamma'
#  'J1939+2134_red_noise_log10_A' 'J1939+2134_red_noise_gamma']
# ['J1944+0907_dm_gp_log10_A' 'J1944+0907_dm_gp_gamma']
# ['J1944+0907_dm_gp_log10_A' 'J1944+0907_dm_gp_gamma'
#  'J1944+0907_red_noise_log10_A' 'J1944+0907_red_noise_gamma']
# ['J1955+2908_dm_gp_log10_A' 'J1955+2908_dm_gp_gamma']
# ['J1955+2908_dm_gp_log10_A' 'J1955+2908_dm_gp_gamma'
#  'J1955+2908_red_noise_log10_A' 'J1955+2908_red_noise_gamma']
# ['J2010-1323_dm_gp_log10_A' 'J2010-1323_dm_gp_gamma']
# ['J2010-1323_dm_gp_log10_A' 'J2010-1323_dm_gp_gamma'
#  'J2010-1323_red_noise_log10_A' 'J2010-1323_red_noise_gamma']
# ['J2019+2425_dm_gp_log10_A' 'J2019+2425_dm_gp_gamma']
# ['J2019+2425_dm_gp_log10_A' 'J2019+2425_dm_gp_gamma'
#  'J2019+2425_red_noise_log10_A' 'J2019+2425_red_noise_gamma']
# ['J2033+1734_dm_gp_log10_A' 'J2033+1734_dm_gp_gamma']
# ['J2033+1734_dm_gp_log10_A' 'J2033+1734_dm_gp_gamma'
#  'J2033+1734_red_noise_log10_A' 'J2033+1734_red_noise_gamma']
# ['J2124-3358_dm_gp_log10_A' 'J2124-3358_dm_gp_gamma']
# ['J2124-3358_dm_gp_log10_A' 'J2124-3358_dm_gp_gamma'
#  'J2124-3358_red_noise_log10_A' 'J2124-3358_red_noise_gamma']
# ['J2129-5721_dm_gp_log10_A' 'J2129-5721_dm_gp_gamma']
# ['J2129-5721_dm_gp_log10_A' 'J2129-5721_dm_gp_gamma'
#  'J2129-5721_red_noise_log10_A' 'J2129-5721_red_noise_gamma']
# ['J2145-0750_dm_gp_log10_A' 'J2145-0750_dm_gp_gamma']
# ['J2145-0750_dm_gp_log10_A' 'J2145-0750_dm_gp_gamma'
#  'J2145-0750_red_noise_log10_A' 'J2145-0750_red_noise_gamma']
# ['J2229+2643_dm_gp_log10_A' 'J2229+2643_dm_gp_gamma']
# ['J2229+2643_dm_gp_log10_A' 'J2229+2643_dm_gp_gamma'
#  'J2229+2643_red_noise_log10_A' 'J2229+2643_red_noise_gamma']
# ['J2317+1439_dm_gp_log10_A' 'J2317+1439_dm_gp_gamma']
# ['J2317+1439_dm_gp_log10_A' 'J2317+1439_dm_gp_gamma'
#  'J2317+1439_red_noise_log10_A' 'J2317+1439_red_noise_gamma']
# ['J2322+2057_dm_gp_log10_A' 'J2322+2057_dm_gp_gamma']
# ['J2322+2057_dm_gp_log10_A' 'J2322+2057_dm_gp_gamma'
#  'J2322+2057_red_noise_log10_A' 'J2322+2057_red_noise_gamma']
# ['J1713+0747_exp1_log10_Amp' 'J1713+0747_exp1_t0'
#  'J1713+0747_exp1_log10_tau']
# ['J1713+0747_exp1_log10_Amp' 'J1713+0747_exp1_t0'
#  'J1713+0747_exp1_log10_tau' 'J1713+0747_red_noise_log10_A'
#  'J1713+0747_red_noise_gamma']
# ['J0030+0451_dm_gp_log10_A' 'J0030+0451_dm_gp_gamma'
#  'J0034-0534_dm_gp_log10_A' 'J0034-0534_dm_gp_gamma'
#  'J0218+4232_dm_gp_log10_A' 'J0218+4232_dm_gp_gamma'
#  'J0437-4715_dm_gp_log10_A' 'J0437-4715_dm_gp_gamma'
#  'J0610-2100_dm_gp_log10_A' 'J0610-2100_dm_gp_gamma'
#  'J0613-0200_dm_gp_log10_A' 'J0613-0200_dm_gp_gamma'
#  'J0621+1002_dm_gp_log10_A' 'J0621+1002_dm_gp_gamma'
#  'J0711-6830_dm_gp_log10_A' 'J0711-6830_dm_gp_gamma'
#  'J0751+1807_dm_gp_log10_A' 'J0751+1807_dm_gp_gamma'
#  'J0900-3144_dm_gp_log10_A' 'J0900-3144_dm_gp_gamma'
#  'J1012+5307_dm_gp_log10_A' 'J1012+5307_dm_gp_gamma'
#  'J1022+1001_dm_gp_log10_A' 'J1022+1001_dm_gp_gamma'
#  'J1024-0719_dm_gp_log10_A' 'J1024-0719_dm_gp_gamma'
#  'J1045-4509_dm_gp_log10_A' 'J1045-4509_dm_gp_gamma'
#  'J1455-3330_dm_gp_log10_A' 'J1455-3330_dm_gp_gamma'
#  'J1600-3053_dm_gp_log10_A' 'J1600-3053_dm_gp_gamma'
#  'J1603-7202_dm_gp_log10_A' 'J1603-7202_dm_gp_gamma'
#  'J1614-2230_dm_gp_log10_A' 'J1614-2230_dm_gp_gamma'
#  'J1640+2224_dm_gp_log10_A' 'J1640+2224_dm_gp_gamma'
#  'J1643-1224_dm_gp_log10_A' 'J1643-1224_dm_gp_gamma'
#  'J1713+0747_dm_gp_log10_A' 'J1713+0747_dm_gp_gamma'
#  'J1721-2457_dm_gp_log10_A' 'J1721-2457_dm_gp_gamma'
#  'J1730-2304_dm_gp_log10_A' 'J1730-2304_dm_gp_gamma'
#  'J1732-5049_dm_gp_log10_A' 'J1732-5049_dm_gp_gamma'
#  'J1738+0333_dm_gp_log10_A' 'J1738+0333_dm_gp_gamma'
#  'J1741+1351_dm_gp_log10_A' 'J1741+1351_dm_gp_gamma'
#  'J1744-1134_dm_gp_log10_A' 'J1744-1134_dm_gp_gamma'
#  'J1751-2857_dm_gp_log10_A' 'J1751-2857_dm_gp_gamma'
#  'J1801-1417_dm_gp_log10_A' 'J1801-1417_dm_gp_gamma'
#  'J1802-2124_dm_gp_log10_A' 'J1802-2124_dm_gp_gamma'
#  'J1804-2717_dm_gp_log10_A' 'J1804-2717_dm_gp_gamma'
#  'J1824-2452A_dm_gp_log10_A' 'J1824-2452A_dm_gp_gamma'
#  'J1843-1113_dm_gp_log10_A' 'J1843-1113_dm_gp_gamma'
#  'J1853+1303_dm_gp_log10_A' 'J1853+1303_dm_gp_gamma'
#  'J1857+0943_dm_gp_log10_A' 'J1857+0943_dm_gp_gamma'
#  'J1903+0327_dm_gp_log10_A' 'J1903+0327_dm_gp_gamma'
#  'J1909-3744_dm_gp_log10_A' 'J1909-3744_dm_gp_gamma'
#  'J1910+1256_dm_gp_log10_A' 'J1910+1256_dm_gp_gamma'
#  'J1911+1347_dm_gp_log10_A' 'J1911+1347_dm_gp_gamma'
#  'J1911-1114_dm_gp_log10_A' 'J1911-1114_dm_gp_gamma'
#  'J1918-0642_dm_gp_log10_A' 'J1918-0642_dm_gp_gamma'
#  'J1939+2134_dm_gp_log10_A' 'J1939+2134_dm_gp_gamma'
#  'J1944+0907_dm_gp_log10_A' 'J1944+0907_dm_gp_gamma'
#  'J1955+2908_dm_gp_log10_A' 'J1955+2908_dm_gp_gamma'
#  'J2010-1323_dm_gp_log10_A' 'J2010-1323_dm_gp_gamma'
#  'J2019+2425_dm_gp_log10_A' 'J2019+2425_dm_gp_gamma'
#  'J2033+1734_dm_gp_log10_A' 'J2033+1734_dm_gp_gamma'
#  'J2124-3358_dm_gp_log10_A' 'J2124-3358_dm_gp_gamma'
#  'J2129-5721_dm_gp_log10_A' 'J2129-5721_dm_gp_gamma'
#  'J2145-0750_dm_gp_log10_A' 'J2145-0750_dm_gp_gamma'
#  'J2229+2643_dm_gp_log10_A' 'J2229+2643_dm_gp_gamma'
#  'J2317+1439_dm_gp_log10_A' 'J2317+1439_dm_gp_gamma'
#  'J2322+2057_dm_gp_log10_A' 'J2322+2057_dm_gp_gamma']
# ['J0030+0451_dm_gp_log10_A' 'J0030+0451_dm_gp_gamma'
#  'J0030+0451_red_noise_gamma' 'J0030+0451_red_noise_log10_A']
# ['J0034-0534_dm_gp_log10_A' 'J0034-0534_dm_gp_gamma'
#  'J0034-0534_red_noise_gamma' 'J0034-0534_red_noise_log10_A']
# ['J0218+4232_dm_gp_log10_A' 'J0218+4232_dm_gp_gamma'
#  'J0218+4232_red_noise_gamma' 'J0218+4232_red_noise_log10_A']
# ['J0437-4715_dm_gp_log10_A' 'J0437-4715_dm_gp_gamma'
#  'J0437-4715_red_noise_gamma' 'J0437-4715_red_noise_log10_A']
# ['J0610-2100_dm_gp_log10_A' 'J0610-2100_dm_gp_gamma'
#  'J0610-2100_red_noise_gamma' 'J0610-2100_red_noise_log10_A']
# ['J0613-0200_dm_gp_log10_A' 'J0613-0200_dm_gp_gamma'
#  'J0613-0200_red_noise_gamma' 'J0613-0200_red_noise_log10_A']
# ['J0621+1002_dm_gp_log10_A' 'J0621+1002_dm_gp_gamma'
#  'J0621+1002_red_noise_gamma' 'J0621+1002_red_noise_log10_A']
# ['J0711-6830_dm_gp_log10_A' 'J0711-6830_dm_gp_gamma'
#  'J0711-6830_red_noise_gamma' 'J0711-6830_red_noise_log10_A']
# ['J0751+1807_dm_gp_log10_A' 'J0751+1807_dm_gp_gamma'
#  'J0751+1807_red_noise_gamma' 'J0751+1807_red_noise_log10_A']
# ['J0900-3144_dm_gp_log10_A' 'J0900-3144_dm_gp_gamma'
#  'J0900-3144_red_noise_gamma' 'J0900-3144_red_noise_log10_A']
# ['J1012+5307_dm_gp_log10_A' 'J1012+5307_dm_gp_gamma'
#  'J1012+5307_red_noise_gamma' 'J1012+5307_red_noise_log10_A']
# ['J1022+1001_dm_gp_log10_A' 'J1022+1001_dm_gp_gamma'
#  'J1022+1001_red_noise_gamma' 'J1022+1001_red_noise_log10_A']
# ['J1024-0719_dm_gp_log10_A' 'J1024-0719_dm_gp_gamma'
#  'J1024-0719_red_noise_gamma' 'J1024-0719_red_noise_log10_A']
# ['J1045-4509_dm_gp_log10_A' 'J1045-4509_dm_gp_gamma'
#  'J1045-4509_red_noise_gamma' 'J1045-4509_red_noise_log10_A']
# ['J1455-3330_dm_gp_log10_A' 'J1455-3330_dm_gp_gamma'
#  'J1455-3330_red_noise_gamma' 'J1455-3330_red_noise_log10_A']
# ['J1600-3053_dm_gp_log10_A' 'J1600-3053_dm_gp_gamma'
#  'J1600-3053_red_noise_gamma' 'J1600-3053_red_noise_log10_A']
# ['J1603-7202_dm_gp_log10_A' 'J1603-7202_dm_gp_gamma'
#  'J1603-7202_red_noise_gamma' 'J1603-7202_red_noise_log10_A']
# ['J1614-2230_dm_gp_log10_A' 'J1614-2230_dm_gp_gamma'
#  'J1614-2230_red_noise_gamma' 'J1614-2230_red_noise_log10_A']
# ['J1640+2224_dm_gp_log10_A' 'J1640+2224_dm_gp_gamma'
#  'J1640+2224_red_noise_gamma' 'J1640+2224_red_noise_log10_A']
# ['J1643-1224_dm_gp_log10_A' 'J1643-1224_dm_gp_gamma'
#  'J1643-1224_red_noise_gamma' 'J1643-1224_red_noise_log10_A']
# ['J1713+0747_dm_gp_log10_A' 'J1713+0747_dm_gp_gamma'
#  'J1713+0747_red_noise_gamma' 'J1713+0747_red_noise_log10_A']
# ['J1721-2457_dm_gp_log10_A' 'J1721-2457_dm_gp_gamma'
#  'J1721-2457_red_noise_gamma' 'J1721-2457_red_noise_log10_A']
# ['J1730-2304_dm_gp_log10_A' 'J1730-2304_dm_gp_gamma'
#  'J1730-2304_red_noise_gamma' 'J1730-2304_red_noise_log10_A']
# ['J1732-5049_dm_gp_log10_A' 'J1732-5049_dm_gp_gamma'
#  'J1732-5049_red_noise_gamma' 'J1732-5049_red_noise_log10_A']
# ['J1738+0333_dm_gp_log10_A' 'J1738+0333_dm_gp_gamma'
#  'J1738+0333_red_noise_gamma' 'J1738+0333_red_noise_log10_A']
# ['J1741+1351_dm_gp_log10_A' 'J1741+1351_dm_gp_gamma'
#  'J1741+1351_red_noise_gamma' 'J1741+1351_red_noise_log10_A']
# ['J1744-1134_dm_gp_log10_A' 'J1744-1134_dm_gp_gamma'
#  'J1744-1134_red_noise_gamma' 'J1744-1134_red_noise_log10_A']
# ['J1751-2857_dm_gp_log10_A' 'J1751-2857_dm_gp_gamma'
#  'J1751-2857_red_noise_gamma' 'J1751-2857_red_noise_log10_A']
# ['J1801-1417_dm_gp_log10_A' 'J1801-1417_dm_gp_gamma'
#  'J1801-1417_red_noise_gamma' 'J1801-1417_red_noise_log10_A']
# ['J1802-2124_dm_gp_log10_A' 'J1802-2124_dm_gp_gamma'
#  'J1802-2124_red_noise_gamma' 'J1802-2124_red_noise_log10_A']
# ['J1804-2717_dm_gp_log10_A' 'J1804-2717_dm_gp_gamma'
#  'J1804-2717_red_noise_gamma' 'J1804-2717_red_noise_log10_A']
# ['J1824-2452A_dm_gp_log10_A' 'J1824-2452A_dm_gp_gamma'
#  'J1824-2452A_red_noise_gamma' 'J1824-2452A_red_noise_log10_A']
# ['J1843-1113_dm_gp_log10_A' 'J1843-1113_dm_gp_gamma'
#  'J1843-1113_red_noise_gamma' 'J1843-1113_red_noise_log10_A']
# ['J1853+1303_dm_gp_log10_A' 'J1853+1303_dm_gp_gamma'
#  'J1853+1303_red_noise_gamma' 'J1853+1303_red_noise_log10_A']
# ['J1857+0943_dm_gp_log10_A' 'J1857+0943_dm_gp_gamma'
#  'J1857+0943_red_noise_gamma' 'J1857+0943_red_noise_log10_A']
# ['J1903+0327_dm_gp_log10_A' 'J1903+0327_dm_gp_gamma'
#  'J1903+0327_red_noise_gamma' 'J1903+0327_red_noise_log10_A']
# ['J1909-3744_dm_gp_log10_A' 'J1909-3744_dm_gp_gamma'
#  'J1909-3744_red_noise_gamma' 'J1909-3744_red_noise_log10_A']
# ['J1910+1256_dm_gp_log10_A' 'J1910+1256_dm_gp_gamma'
#  'J1910+1256_red_noise_gamma' 'J1910+1256_red_noise_log10_A']
# ['J1911+1347_dm_gp_log10_A' 'J1911+1347_dm_gp_gamma'
#  'J1911+1347_red_noise_gamma' 'J1911+1347_red_noise_log10_A']
# ['J1911-1114_dm_gp_log10_A' 'J1911-1114_dm_gp_gamma'
#  'J1911-1114_red_noise_gamma' 'J1911-1114_red_noise_log10_A']
# ['J1918-0642_dm_gp_log10_A' 'J1918-0642_dm_gp_gamma'
#  'J1918-0642_red_noise_gamma' 'J1918-0642_red_noise_log10_A']
# ['J1939+2134_dm_gp_log10_A' 'J1939+2134_dm_gp_gamma'
#  'J1939+2134_red_noise_gamma' 'J1939+2134_red_noise_log10_A']
# ['J1944+0907_dm_gp_log10_A' 'J1944+0907_dm_gp_gamma'
#  'J1944+0907_red_noise_gamma' 'J1944+0907_red_noise_log10_A']
# ['J1955+2908_dm_gp_log10_A' 'J1955+2908_dm_gp_gamma'
#  'J1955+2908_red_noise_gamma' 'J1955+2908_red_noise_log10_A']
# ['J2010-1323_dm_gp_log10_A' 'J2010-1323_dm_gp_gamma'
#  'J2010-1323_red_noise_gamma' 'J2010-1323_red_noise_log10_A']
# ['J2019+2425_dm_gp_log10_A' 'J2019+2425_dm_gp_gamma'
#  'J2019+2425_red_noise_gamma' 'J2019+2425_red_noise_log10_A']
# ['J2033+1734_dm_gp_log10_A' 'J2033+1734_dm_gp_gamma'
#  'J2033+1734_red_noise_gamma' 'J2033+1734_red_noise_log10_A']
# ['J2124-3358_dm_gp_log10_A' 'J2124-3358_dm_gp_gamma'
#  'J2124-3358_red_noise_gamma' 'J2124-3358_red_noise_log10_A']
# ['J2129-5721_dm_gp_log10_A' 'J2129-5721_dm_gp_gamma'
#  'J2129-5721_red_noise_gamma' 'J2129-5721_red_noise_log10_A']
# ['J2145-0750_dm_gp_log10_A' 'J2145-0750_dm_gp_gamma'
#  'J2145-0750_red_noise_gamma' 'J2145-0750_red_noise_log10_A']
# ['J2229+2643_dm_gp_log10_A' 'J2229+2643_dm_gp_gamma'
#  'J2229+2643_red_noise_gamma' 'J2229+2643_red_noise_log10_A']
# ['J2317+1439_dm_gp_log10_A' 'J2317+1439_dm_gp_gamma'
#  'J2317+1439_red_noise_gamma' 'J2317+1439_red_noise_log10_A']
# ['J2322+2057_dm_gp_log10_A' 'J2322+2057_dm_gp_gamma'
#  'J2322+2057_red_noise_gamma' 'J2322+2057_red_noise_log10_A']

# %%
# check sampler is setup correctly
if emp_dist_path is not None:
    print(f"Using empirical distributions file path: {emp_dist_path}")
else:
    print("No empirical distributions file given")
sampler = setup_sampler(pta, outdir=outdir, groups=gr, resume=False,
                        human='bjorn.larsen', empirical_distr=emp_dist_path)
# Out:
# Using empirical distributions file path: /vast/palmer/home.grace/bbl29/IPTA_DR2_analysis/empdists/dr2full_stdnoise.pkl
# extending empirical distributions to priors...
#
# Attempting to add empirical proposals...
#
# Adding red noise prior draws...
#
# Adding DM GP noise prior draws...
